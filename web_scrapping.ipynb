# %%
import re
import json
import spacy
import nltk
import requests
import sklearn_crfsuite
from bs4 import BeautifulSoup
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from datasets import load_dataset
from sklearn_crfsuite import metrics
from seqeval.metrics import classification_report, accuracy_score, precision_score, f1_score
from rdflib import Graph, URIRef, Literal, Namespace
from rdflib.namespace import RDF, RDFS
import urllib.parse
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import time
import random

from pykeen.pipeline import pipeline
from pykeen.triples import TriplesFactory
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
import torch
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# %% [markdown]
# ###### nltk

# %%
nltk.download("punkt")
nltk.download("stopwords")
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\rafro\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\rafro\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\rafro\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# # === PART 1 ===

# %% [markdown]
# ## TASK 1: MODEL FOR NER

# %% [markdown]
# ### 1. TEXT CLEANING & PREPROCESSING

# %%
def clean_text(text):
    text = re.sub(r"<.*?>", "", text)
    text = re.sub(r"[^a-zA-Z0-9 ]", "", text)
    text = text.lower()
    words = word_tokenize(text)
    words = [w for w in words if w not in stopwords.words("english")]
    lemmatizer = WordNetLemmatizer()
    words = [lemmatizer.lemmatize(w) for w in words]
    return " ".join(words)

# %%
raw_text = "<p>Apple was founded by Steve Jobs.</p>"
cleaned_text = clean_text(raw_text)
print("Cleaned Text:", cleaned_text)
# Out:
# Cleaned Text: apple founded steve job

# %% [markdown]
# ### 2. NAMED ENTITY RECOGNITION (NER)

# %%
# Load the CoNLL-2003 dataset 
dataset = load_dataset("conll2003", trust_remote_code=True)
train_dataset = dataset['train'] 
validation_dataset = dataset['validation'] 
test_dataset = dataset['test'] 
# Example: Print the first example from the training set 
print(train_dataset[0])
# Out:
# {'id': '0', 'tokens': ['EU', 'rejects', 'German', 'call', 'to', 'boycott', 'British', 'lamb', '.'], 'pos_tags': [22, 42, 16, 21, 35, 37, 16, 21, 7], 'chunk_tags': [11, 21, 11, 12, 21, 22, 11, 12, 0], 'ner_tags': [3, 0, 7, 0, 0, 0, 7, 0, 0]}

# %%
# Map NER tag indices to actual labels
ner_labels = dataset["train"].features["ner_tags"].feature.int2str
print(ner_labels)
# Out:
# <bound method ClassLabel.int2str of ClassLabel(names=['O', 'B-PER', 'I-PER', 'B-ORG', 'I-ORG', 'B-LOC', 'I-LOC', 'B-MISC', 'I-MISC'], id=None)>

# %%
# Feature Extraction for CRF Model
def extract_features(doc):
    return [{"word": w} for w in doc["tokens"]]

def get_labels(doc):
    return [ner_labels(label) for label in doc["ner_tags"]]

# %%
X_train = [extract_features(sent) for sent in train_dataset]
y_train = [get_labels(sent) for sent in train_dataset]
X_test = [extract_features(sent) for sent in test_dataset]
y_test = [get_labels(sent) for sent in test_dataset]

print("Sample Features:", X_train[0])
print("Sample Labels:", y_train[0])
# Out:
# Sample Features: [{'word': 'EU'}, {'word': 'rejects'}, {'word': 'German'}, {'word': 'call'}, {'word': 'to'}, {'word': 'boycott'}, {'word': 'British'}, {'word': 'lamb'}, {'word': '.'}]
# Sample Labels: ['B-ORG', 'O', 'B-MISC', 'O', 'O', 'O', 'B-MISC', 'O', 'O']

# %%
# Train CRF model
crf = sklearn_crfsuite.CRF(
    algorithm="lbfgs",
    c1=0.1,
    c2=0.1,
    max_iterations=100,
    all_possible_transitions=False
)
crf.fit(X_train, y_train)
# Out:
# CRF(algorithm='lbfgs', all_possible_transitions=False, c1=0.1, c2=0.1,
#     max_iterations=100)

# %%
# Evaluate CRF model
y_pred = crf.predict(X_test)

# %%
nlp = spacy.load("en_ner_conll03")

# Convert spaCy predictions to IOB format aligned with test set
def spacy_ner_predict(sentences):
    y_preds = []
    for sent in sentences:
        doc = nlp(" ".join(sent["tokens"]))
        pred_tags = ["O"] * len(sent["tokens"])
        for ent in doc.ents:
            start, end, label = ent.start, ent.end, ent.label_
            if start < len(pred_tags):
                pred_tags[start] = f"B-{label}"
                for i in range(start+1, min(end, len(pred_tags))):
                    pred_tags[i] = f"I-{label}"
        y_preds.append(pred_tags)
    return y_preds

# Get gold labels from test set
ner_labels = dataset["train"].features["ner_tags"].feature.int2str
y_true = [[ner_labels(tag) for tag in sent["ner_tags"]] for sent in test_dataset]

# %%
# Evaluate spaCy predictions
y_pred_spacy = spacy_ner_predict(test_dataset)

# %%
# Compare CRF and spaCy predictions
print("📊 CRF Classification Report:")
print(metrics.flat_classification_report(y_test, y_pred))
print("📊 spaCy Classification Report:")
print(classification_report(y_true, y_pred_spacy))
# Out:
# 📊 CRF Classification Report:
#               precision    recall  f1-score   support
#
#        B-LOC       0.89      0.78      0.83      1668
#       B-MISC       0.83      0.67      0.74       702
#        B-ORG       0.81      0.55      0.66      1661
#        B-PER       0.74      0.43      0.55      1617
#        I-LOC       0.42      0.66      0.51       257
#       I-MISC       0.63      0.60      0.61       216
#        I-ORG       0.53      0.63      0.58       835
#        I-PER       0.72      0.55      0.62      1156
#            O       0.94      0.97      0.95     38323
#
#     accuracy                           0.91     46435
#    macro avg       0.72      0.65      0.67     46435
# weighted avg       0.90      0.91      0.90     46435
#
# 📊 spaCy Classification Report:
#               precision    recall  f1-score   support
#
#          LOC       0.69      0.64      0.66      1668
#         MISC       0.67      0.63      0.65       702
#          ORG       0.70      0.67      0.68      1661
#          PER       0.63      0.65      0.64      1617
#
#    micro avg       0.67      0.65      0.66      5648
#    macro avg       0.67      0.65      0.66      5648
# weighted avg       0.67      0.65      0.66      5648

# %% [markdown]
# 📊 Named Entity Recognition: CRF vs spaCy Pretrained Model
# | Model   | Label Format                | Notes                                               |
# |---------|-----------------------------|-----------------------------------------------------|
# | CRF     | B-LOC, I-ORG, O, etc.       | Uses BIO tagging (Begin, Inside, Outside) for token-level labeling |
# | spaCy   | LOC, PER, ORG, MISC         | Returns full entity spans, not token-level BIO tags    |
#
# Note: spaCy internally uses BILUO tags during training, but outputs clean entity spans without B-/I- prefixes. CRF evaluates per-token; spaCy evaluates per-entity.

# %% [markdown]
# 📈 Performance Comparison (weighted avrg)
# | Metric     | CRF Model (Token-level) | spaCy Pretrained (Entity-level) |
# |------------|--------------------------|----------------------------------|
# | Precision  | 0.90                     | 0.67                             |
# | Recall     | 0.91                     | 0.65                             |
# | F1-Score   | 0.90                     | 0.66                             |
#
# - The CRF model, trained specifically on the CoNLL-2003 dataset, achieves higher precision, recall, and F1-score, reflecting strong token-level performance.
#
# - The spaCy pretrained model performs reasonably well but slightly lower. Its strength lies in ease of use, span-level predictions, and pretrained generalization.
#
# - The difference is due to:
#
#     - CRF evaluates per-token BIO tags.
#
#     - spaCy evaluates entire named entity spans, which is stricter (e.g., must capture "New York City" fully).
#
# - For fine-grained, high-accuracy tasks, a CRF trained on your specific dataset is more effective.
#
# - For general-purpose NER across diverse texts, spaCy offers strong performance with zero training.

# %%
def extract_crf_entities(test_data, predictions):
    extracted = []
    for sent, tags in zip(test_data, predictions):
        tokens = sent["tokens"]
        i = 0
        while i < len(tags):
            tag = tags[i]
            if tag.startswith("B-"):
                entity = tokens[i]
                start = i
                label = tag[2:]
                i += 1
                while i < len(tags) and tags[i].startswith("I-"):
                    entity += " " + tokens[i]
                    i += 1
                end = i - 1
                extracted.append({"entity": entity, "label": label, "start": start, "end": end})
            else:
                i += 1
    return extracted

crf_entities = extract_crf_entities(test_dataset, y_pred)

# Save to JSON file
with open("crf_entities.json", "w") as f:
    json.dump(crf_entities, f, indent=2)

# %%
def extract_spacy_entities(test_data, model):
    all_entities = []
    for sent in test_data:
        tokens = sent["tokens"]
        text = " ".join(tokens)
        doc = model(text)
        for ent in doc.ents:
            all_entities.append({
                "entity": ent.text,
                "label": ent.label_,
                "start": ent.start,
                "end": ent.end - 1
            })
    return all_entities

spacy_entities = extract_spacy_entities(test_dataset, nlp)

# Save to JSON file
with open("spacy_entities.json", "w") as f:
    json.dump(spacy_entities, f, indent=2)

# %% [markdown]
# ### 3. RELATION EXTRACTION (RE)

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ------- -------------------------------- 2.4/12.8 MB 12.2 MB/s eta 0:00:01
#      -------------- ------------------------- 4.7/12.8 MB 11.9 MB/s eta 0:00:01
#      ---------------------- ----------------- 7.1/12.8 MB 11.8 MB/s eta 0:00:01
#      ------------------------------ --------- 9.7/12.8 MB 11.8 MB/s eta 0:00:01
#      ------------------------------------ -- 12.1/12.8 MB 12.0 MB/s eta 0:00:01
#      --------------------------------------- 12.8/12.8 MB 11.2 MB/s eta 0:00:00
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %% [markdown]
# The goal is to extract relations of the form (subject, predicate, object) where:
# - Subject: The entity performing the action (or passive subject).
# - Predicate: The verb that describes the action.
# - Object: The entity affected by the action (or passive agent).

# %% [markdown]
# Application of extraction rules:
# - Input Text: "Apple was founded by Steve Jobs."
# - spaCy Process: The text is processed using the spaCy NLP pipeline.
# - Subject Extraction:
#     - Token: "Apple" (dependency: nsubjpass).
#     - Recognized as the subject of the sentence.
# - Predicate Extraction:
#     - Token: "founded" (head of "Apple" and main verb of the sentence).
#     - Lemma: "found" (the base form of the verb).
# - Agent (Object of Preposition):
#     - The phrase “by Steve Jobs” is detected as a prepositional phrase.
#     - "by" is the preposition, and "Steve Jobs" is the object of the preposition (pobj).

# %%
nlp_re = spacy.load("en_core_web_sm")
txt = "Apple was founded by Steve Jobs."
doc = nlp_re(txt)
relations = []
# Iterate over tokens in the document
for token in doc:
    # Check for passive subject (nsubjpass) and the verb (ROOT)
    if token.dep_ == "nsubjpass" and token.head.pos_ == "VERB":
        subject = token.text  # Passive subject
        predicate = token.head.lemma_  # Predicate (base form of the verb)
        
        # Search for the prepositional phrase indicating the agent
        for child in token.head.children:
            if child.dep_ == "agent":  # Look for the agent (usually in 'by' phrase)
                for obj in child.children:
                    if obj.dep_ == "pobj":  # The object of the preposition (agent)
                        obj_text = obj.text
                        # Append the relation to the list
                        relations.append((subject, predicate, obj_text))
print(relations)
# Out:
# [('Apple', 'found', 'Jobs')]

# %% [markdown]
# It works well, we will implement this code in an extraction function to make it go through our test_dataset and save it.

# %%
def extract_relations(test_data, model):
    relations = []
    for sent in test_data:
        tokens = sent["tokens"]
        text = " ".join(tokens)
        doc = model(text)
        for token in doc:
            if token.dep_ == "nsubjpass" and token.head.pos_ == "VERB":
                subject = token.text
                predicate = token.head.lemma_
                for child in token.head.children:
                    if child.dep_ == "agent":
                        for agent in child.children:
                            if agent.dep_ == "pobj":
                                obj = agent.text
                                relations.append((subject, predicate, obj))
    return relations

core_web_relations = extract_relations(test_dataset, nlp_re)

# Save to JSON file
with open("core_web_relations.json", "w") as f:
    json.dump(core_web_relations, f, indent=2)

# %% [markdown]
# ### 4. KNOWLEDGE GRAPH BUILDING

# %% [markdown]
# We will work with the entities from the crf extraction, saved in crf_entities.json as well as with the relations saved in core_web_relations.json.

# %%
EX = Namespace("http://example.org/")
g = Graph()

with open("core_web_relations.json", "r") as relations_file:
    relations = json.load(relations_file)

with open("crf_entities.json", "r") as entities_file:
    entities = json.load(entities_file)

# %%
# Helper function to make entity names URI-safe
def make_uri_safe(name):
    return urllib.parse.quote(name.replace(" ", "_"))

# %% [markdown]
# This function will resolve the entities name problem as there are spaces in the .json

# %%
for relation in relations:
    subject, predicate, obj = relation

    # Add triples to the graph
    g.add((URIRef(EX[subject]), URIRef(EX[predicate]), URIRef(EX[obj])))

for entity in entities:
    entity_name = entity.get("entity", None)
    entity_label = entity.get("label", None)

    if entity_name and entity_label:
        # Make the entity name URI-safe
        safe_entity_name = make_uri_safe(entity_name)
        # Add the entity with its type (label) to the graph
        g.add((URIRef(EX[safe_entity_name]), RDF.type, URIRef(EX[entity_label])))

# %%
query = """
SELECT ?subject ?predicate ?object
WHERE {
    # ?subject ?predicate ?object .
}
"""
results = g.query(query)
for row in results:
    print(f"Subject: {row.subject}, Predicate: {row.predicate}, Object: {row.object}")
# Out:
# Subject: http://example.org/Portugal, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/Moslem, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/MISC
# Subject: http://example.org/OAKLAND, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Carlos_Secretario, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/28%2C418, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/NEW, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/Hosni_Mubarak, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Partizan, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/40-1_Chendo_Porlan_33-1_Miguel_Nadal, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/PORT_LOUIS_1996-12-06, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Barley_110.8_1203.4_506.0_48.2_941.0_786.6, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Preston, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/OPEC_basket, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Ayr, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/ATLANTIC_DIVISION, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/MISC
# Subject: http://example.org/Humane_Society, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/World_Cup, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/MISC
# Subject: http://example.org/12/15/2006_145M, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Buza, Predicate: http://example.org/overpower, Object: http://example.org/police
# Subject: http://example.org/Francis_Wewengken, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/BELFAST_1996-12-06, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/26%3D_Michaela, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Arabic, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/MISC
# Subject: http://example.org/ALPINE_SKIING-WOMEN_%27S_DOWNHILL_WINNER_PROFILE, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Jeff_Bean, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Franziska_Schenk, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Inverness_Thistle, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/S._Campbell, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/David_Snow, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/153_243, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/NORDIC_SKIING-WORLD_CUP, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/MISC
# Subject: http://example.org/Peterborough, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Thompson, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Sherwin_Campbell, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Greek, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/MISC
# Subject: http://example.org/Andrea_Castellani, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Jose_Ramos, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Irish, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/MISC
# Subject: http://example.org/Takuya_Takagi, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/53.04%29., Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Daniel_Manu, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Jim_Harbaugh, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Burundi, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/AMSTERDAM_1996-12-07, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/Rye_4.1_60.7_57.9_3.0_10.7_18.9, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Hartlepool, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Senate, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/CIS, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/Brian_Shimer, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Troy_Benson, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/L._Germon, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/NY_RANGERS, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Walsall, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Rui_Barros, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Oscar_Luigi, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/U.S._Municipal_Desk, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/National_and_Labour, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/half, Predicate: http://example.org/suffer, Object: http://example.org/children
# Subject: http://example.org/Czech_Civic_Democratic_Party, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Slovenia_432, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/PLO, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Graafschap_Doetinchem, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Bali_1996-12-07, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/West_Ham, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Wasim_Akram, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Valencia, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/LONDON_1996-12-06, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/RTRS, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/WORLD_CUP, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/MISC
# Subject: http://example.org/National_Air_Traffic_Services_Ltd, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Dan_Crowley, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/J._Murray, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Robert, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/F.A._Challenge_Cup, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/MISC
# Subject: http://example.org/Rosemary_Bennett, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Canadian, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/MISC
# Subject: http://example.org/Chelsea, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Canadian_Wheat_Board, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/O_Globo, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/
Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER

# %% [markdown]
# We decided to serialize the graph to a .ttl file

# %%
g.serialize("test_data_knowledge_graph.ttl", format="turtle")
num_triples = len(g)
print(f"The graph contains {num_triples} triples.")
# Out:
# The graph contains 1912 triples.

# %% [markdown]
# Now we want to run the programm on the following text : Star Wars IV is a Movie where there are different kinds of creatures, like humans and wookies. Some creatures are Jedis; for instance, the human Luke is a Jedi, and Master Yoda – for whom the species is not known – is also a Jedi. The wookie named Chewbacca is Han’s co-pilot on the Millennium Falcon starship. The speed of Millennium Falcon is 1.5 (above the speed of light!)

# %%
# Define a namespace
EX = Namespace("http://sw.org/")

# Create an RDF graph
g = Graph()

# Add entities and their types
g.add((URIRef(EX["Star_Wars_IV"]), RDF.type, URIRef(EX["Movie"])))
g.add((URIRef(EX["humans"]), RDF.type, URIRef(EX["Species"])))
g.add((URIRef(EX["wookies"]), RDF.type, URIRef(EX["Species"])))
g.add((URIRef(EX["Luke"]), RDF.type, URIRef(EX["Human"])))
g.add((URIRef(EX["Luke"]), RDF.type, URIRef(EX["Jedi"])))
g.add((URIRef(EX["Master_Yoda"]), RDF.type, URIRef(EX["Jedi"])))
g.add((URIRef(EX["Master_Yoda"]), RDF.type, URIRef(EX["Unknown_Species"])))
g.add((URIRef(EX["Chewbacca"]), RDF.type, URIRef(EX["Wookie"])))
g.add((URIRef(EX["Millennium_Falcon"]), RDF.type, URIRef(EX["Starship"])))

# Add relations
g.add((URIRef(EX["Chewbacca"]), URIRef(EX["is_co_pilot_of"]), URIRef(EX["Millennium_Falcon"])))
g.add((URIRef(EX["Millennium_Falcon"]), URIRef(EX["has_speed"]), Literal(1.5)))
g.add((URIRef(EX["Millennium_Falcon"]), URIRef(EX["speed_unit"]), Literal("above the speed of light")))

# Serialize the graph to a file (optional)
g.serialize("star_wars_knowledge_graph.ttl", format="turtle")

# SPARQL query to verify the graph
query = """
SELECT ?subject ?predicate ?object
WHERE {
    # ?subject ?predicate ?object .
}
"""

# Execute the query
results = g.query(query)

# Print the results
for row in results:
    print(f"Subject: {row.subject}, Predicate: {row.predicate}, Object: {row.object}")
# Out:
# Subject: http://sw.org/Luke, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://sw.org/Human
# Subject: http://sw.org/Master_Yoda, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://sw.org/Unknown_Species
# Subject: http://sw.org/Star_Wars_IV, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://sw.org/Movie
# Subject: http://sw.org/Luke, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://sw.org/Jedi
# Subject: http://sw.org/Chewbacca, Predicate: http://sw.org/is_co_pilot_of, Object: http://sw.org/Millennium_Falcon
# Subject: http://sw.org/Millennium_Falcon, Predicate: http://sw.org/has_speed, Object: 1.5
# Subject: http://sw.org/Millennium_Falcon, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://sw.org/Starship
# Subject: http://sw.org/Millennium_Falcon, Predicate: http://sw.org/speed_unit, Object: above the speed of light
# Subject: http://sw.org/wookies, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://sw.org/Species
# Subject: http://sw.org/humans, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://sw.org/Species
# Subject: http://sw.org/Master_Yoda, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://sw.org/Jedi
# Subject: http://sw.org/Chewbacca, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://sw.org/Wookie

# %% [markdown]
# ## TASK 2: PIPELINE FOR KNOWLEDGE GRAPH CONSTRUCTION

# %% [markdown]
# ### 1. FETCH NEWS ARTICLE

# %% [markdown]
# #### Failed attempts at scrapping reuters

# %%
def fetch_reuters_articles():
    url = "https://www.reuters.com/world/"
    articles = []

    # Fetch the HTML content of the category page
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
    }
    session = requests.Session()
    response = session.get(url, headers=headers)
    if response.status_code != 200:
        print(f"Failed to fetch the category page. Status code: {response.status_code}")
        return articles
    
    # Parse the category page
    soup = BeautifulSoup(response.text, "html.parser")
    for article in soup.find_all("a", attrs={"data-testid": "Link"}, limit=10): #We begin by finding 10 links
        href = article.get("href")
        if href and href.startswith("/"):  # Ensure it's a relative link
            article_url = "https://www.reuters.com" + href

            # Fetch the article page
            article_response = requests.get(article_url)
            if article_response.status_code != 200:
                print(f"Failed to fetch article: {article_url}")
                continue

            # Parse the article page
            article_soup = BeautifulSoup(article_response.text, "html.parser")

            # Extract the title
            title = article_soup.find("h1").get_text(strip=True) if article_soup.find("h1") else "No Title Found"

            # Extract the publication date
            date = article_soup.find("time")
            publication_date = date.get("datetime") if date else "No Date Found"

            # Extract the main content
            content = []
            for paragraph in article_soup.find_all("p"):
                content.append(paragraph.get_text(strip=True))
            main_content = " ".join(content)

            # Store the article data
            articles.append({
                "url": article_url,
                "title": title,
                "publication_date": publication_date,
                "content": main_content
            })

    return articles

# %%
articles = fetch_reuters_articles()
# Out:
# Failed to fetch the category page. Status code: 401

# %% [markdown]
# We can't seem to succeed at fetching reuters so we will try with selenium and a chrome driver

# %%
def fetch_reuters_articles_with_selenium():
    url = "https://www.reuters.com/world/"
    articles = []

    # Set up Selenium WebDriver
    chrome_driver_path = "C:\Program Files\chromedriver-win64\chromedriver.exe"
    service = Service(chrome_driver_path)
    driver = webdriver.Chrome(service=service)

    try:
        # Step 1: Open the category page
        driver.get(url)
        time.sleep(3)  # Wait for the page to load
    
        # Step 2: Extract article links
        soup = BeautifulSoup(driver.page_source, "html.parser")
        for article in soup.find_all("a", attrs={"data-testid": "Link"}, limit=11):  # Adjust the selector if needed
            href = article.get("href")
            if href and href.startswith("/"):  # Ensure it's a relative link
                article_url = "https://www.reuters.com" + href

                # Step 3: Open the article page
                driver.get(article_url)
                time.sleep(3)  # Wait for the page to load

                # Parse the article page
                article_soup = BeautifulSoup(driver.page_source, "html.parser")

                # Extract the title
                title = article_soup.find("h1").get_text(strip=True)

                # Extract the publication date
                date = article_soup.find("time")
                publication_date = date.get("datetime") if date else "No Date Found"

                # Extract the main content
                content = []
                for paragraph in article_soup.find_all("p"):
                    content.append(paragraph.get_text(strip=True))
                main_content = " ".join(content)

                # Store the article data
                articles.append({
                    "url": article_url,
                    "title": title,
                    "publication_date": publication_date,
                    "content": main_content
                })

                # Go back to the category page
                driver.back()
                time.sleep(2)  # Wait for the page to reload

    finally:
        # Close the browser
        driver.quit()

    return articles

# %%
def fetch_reuters_articles_selenium():
    # Configure Chrome options for headless browsing (optional)
    options = Options()
    options.add_argument("--headless")  # Run in headless mode
    options.add_argument("--disable-gpu")  # Disable GPU acceleration
    options.add_argument("--no-sandbox")  # Bypass OS security model
    options.add_argument("--disable-dev-shm-usage")  # Overcome limited resource problems
    # Set up Selenium WebDriver
    chrome_driver_path = "C:\Program Files\chromedriver-win64\chromedriver.exe"
    service = Service(chrome_driver_path)

    # Initialize the Chrome webdriver
    driver = webdriver.Chrome(service=service, options=options)
    
    # URL of Reuters World section
    url = "https://www.reuters.com/world/"

    # Load the page using Selenium
    driver.get(url)

    # Get the page source after JavaScript execution
    page_source = driver.page_source

    # Close the browser
    driver.quit()

    # Parse the HTML content with BeautifulSoup
    soup = BeautifulSoup(page_source, "html.parser")
    print(soup.prettify())
    articles = []  # Initialize an empty list to store articles

    # Extract the first 10 articles
    for article in soup.find_all("a", attrs={"data-testid": "Link"}, limit=11):  # Adjust the selector if needed
        href = article.get("href")
        if href and href.startswith("/"):  # Ensure it's a relative link
            article_url = "https://www.reuters.com" + href

            # Step 3: Open the article page
            driver.get(article_url)
            time.sleep(3)  # Wait for the page to load

            # Parse the article page
            article_soup = BeautifulSoup(driver.page_source, "html.parser")

            # Extract the title
            title = article_soup.find("h1").get_text(strip=True)

            # Extract the publication date
            date = article_soup.find("time")
            publication_date = date.get("datetime") if date else "No Date Found"

            # Extract the main content
            content = []
            for paragraph in article_soup.find_all("p"):
                content.append(paragraph.get_text(strip=True))
            main_content = " ".join(content)

            # Store the article data
            articles.append({
                "url": article_url,
                "title": title,
                "publication_date": publication_date,
                "content": main_content
            })

    return articles

# %%
articles = fetch_reuters_articles_selenium()
# Out:
# <html lang="fr">
#  <head>
#   <title>
#    reuters.com
#   </title>
#   <style>
#    #cmsg{animation: A 1.5s;}@keyframes A{0%{opacity:0;}99%{opacity:0;}100%{opacity:1;}}
#   </style>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#  </head>
#  <body style="margin:0">
#   <script data-cfasync="false">
#    var dd={'rt':'c','cid':'AHrlqAAAAAMAq6OZXDLPCSQATYg8_Q==','hsh':'2013457ADA70C67D6A4123E0A76873','t':'fe','qp':'','s':46743,'e':'bdbff913f6051f687c9ab6f5c8bc9a678f613c05f01ada95bb02880540c43283','host':'geo.captcha-delivery.com','cookie':'SD8S~rnct2IzXM3psZE3MjqsCK7eOZVm3wHgB2UiMh2c1fiZ3a5Zgll1qgopDKLCPHOB5m7X_g8N_H_hhrYTwrDXnzN_g4dyJDpdFyD4hmodyfZgxe~5Ni3Ul6AWQ3I0'}
#   </script>
#   <script data-cfasync="false" src="https://ct.captcha-delivery.com/c.js">
#   </script>
#   <iframe border="0" frameborder="0" height="100%" sandbox="allow-scripts allow-same-origin allow-forms" scrolling="yes" src="https://geo.captcha-delivery.com/captcha/?initialCid=AHrlqAAAAAMAq6OZXDLPCSQATYg8_Q%3D%3D&amp;hash=2013457ADA70C67D6A4123E0A76873&amp;cid=SD8S~rnct2IzXM3psZE3MjqsCK7eOZVm3wHgB2UiMh2c1fiZ3a5Zgll1qgopDKLCPHOB5m7X_g8N_H_hhrYTwrDXnzN_g4dyJDpdFyD4hmodyfZgxe~5Ni3Ul6AWQ3I0&amp;t=fe&amp;referer=https%3A%2F%2Fwww.reuters.com%2Fworld%2F&amp;s=46743&amp;e=bdbff913f6051f687c9ab6f5c8bc9a678f613c05f01ada95bb02880540c43283&amp;dm=cd" style="height:100vh;" title="DataDome CAPTCHA" width="100%">
#   </iframe>
#  </body>
# </html>

# %%
def fetch_reuters_articles_selenium2():
    # Configure Chrome options
    options = Options()
    options.add_argument("--disable-blink-features=AutomationControlled")
    options.add_argument("start-maximized")
    options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36")
    
    # Set up Selenium WebDriver
    chrome_driver_path = "C:\\Program Files\\chromedriver-win64\\chromedriver.exe"
    service = Service(chrome_driver_path)

    # Initialize the Chrome webdriver
    driver = webdriver.Chrome(service=service, options=options)
    
    # Open the page
    driver.get("https://www.reuters.com/world/")
    time.sleep(10)  # Wait for CAPTCHA to be solved manually

    # Extract page source after CAPTCHA is solved
    page_source = driver.page_source
    print(page_source)

    driver.quit()
    # Parse the HTML content with BeautifulSoup
    soup = BeautifulSoup(page_source, "html.parser")
    print(soup.prettify())
    articles = []  # Initialize an empty list to store articles

    # Extract the first 10 articles
    for article in soup.find_all("a", attrs={"data-testid": "Link"}, limit=11):  # Adjust the selector if needed
        href = article.get("href")
        if href and href.startswith("/"):  # Ensure it's a relative link
            article_url = "https://www.reuters.com" + href

            # Step 3: Open the article page
            driver.get(article_url)
            time.sleep(3)  # Wait for the page to load

            # Parse the article page
            article_soup = BeautifulSoup(driver.page_source, "html.parser")

            # Extract the title
            title = article_soup.find("h1").get_text(strip=True)

            # Extract the publication date
            date = article_soup.find("time")
            publication_date = date.get("datetime") if date else "No Date Found"

            # Extract the main content
            content = []
            for paragraph in article_soup.find_all("p"):
                content.append(paragraph.get_text(strip=True))
            main_content = " ".join(content)

            # Store the article data
            articles.append({
                "url": article_url,
                "title": title,
                "publication_date": publication_date,
                "content": main_content
            })

    return articles

# %% [markdown]
# #### Succeded scrapping bbc

# %% [markdown]
# We tried a lot of thing to bypass the captcha and other various problem encountered while scrapping reuters.
# Thus, we will now try to scrap www.bbc.com

# %%
def fetch_bbc_articles():
    chrome_options = Options() 
    chrome_options.add_argument("--headless")  # Run Chrome in headless mode
    chrome_options.add_argument("--no-sandbox")  # Bypass OS security model
    chrome_options.add_argument("--disable-dev-shm-usage") # Overcome limited resource problems

    driver = webdriver.Chrome(options=chrome_options) 
    url = "https://www.bbc.com/sport"
    driver.get(url)

    page_source = driver.page_source
    soup = BeautifulSoup(page_source, "html.parser")

    articles = []

    # Find all article links
    for article in soup.find_all("a", class_="ssrcss-sxweo-PromoLink exn3ah95", limit=10):
        href = article.get("href")
        if href and href.startswith("/sport"):  # Ensure it's a valid BBC News link
            article_url = f"https://www.bbc.com{href}"

            # Fetch the article page
            article_response = requests.get(article_url)
            article_soup = BeautifulSoup(article_response.content, "html.parser")

            # Extract the title
            title = article_soup.find("h1").get_text(strip=True) if article_soup.find("h1") else "No Title Found"

            # Extract the publication date
            date = article_soup.find("time")
            publication_date = date.get("datetime") if date else "No Date Found"

            # Extract the main content
            content = []
            for paragraph in article_soup.find_all("p"):
                content.append(paragraph.get_text(strip=True))
            main_content = " ".join(content)

            # Store the article data
            articles.append({
                "title": title,
                "url": article_url,
                "publication_date": publication_date,
                "content": main_content,
            })

    driver.quit()
    return articles

# %%
articles = fetch_bbc_articles()

# %%
len(articles)
# Out:
# 10

# %%
for article in articles:
    print("Title:", article['title'])
    print("Publication Date:", article['publication_date'])
    print("Content:", article['content'][:200])
    print("URL:", article['url'])
# Out:
# Title: 'Welcome to the club' - Woods leads tributes to McIlroy
# Publication Date: 2025-04-14T02:37:45.803Z
# Content: This video can not be played McIlroy's dramatic Masters triumph Tiger Woods was among the first to congratulate Rory McIlroy on winning the Masters, welcoming him to an exclusive club of men's players
# URL: https://www.bbc.com/sport/golf/articles/c4gr8nnr7zeo
# Title: Modric to become Swansea minority owner
# Publication Date: 2025-04-14T14:07:54.275Z
    nlp_re = spacy.load("en_core_web_sm")

    # Perform minimal cleaning to preserve the structure of the text
    def clean_text(text):
        print("Original Text:", text)
        # Remove HTML tags
        text = re.sub(r"<.*?>", "", text)
        # Remove excessive whitespace
        text = re.sub(r"\s+", " ", text).strip()
        print("Cleaned Text:", text)
        return text

    # Helper function to extract entities using spaCy NER
    def extract_entities(text, model):
        doc = model(text)
        entities = [{"entity": ent.text, "label": ent.label_} for ent in doc.ents]
        print(entities)
        return entities

    # Helper function to extract relations using spaCy RE
    def extract_relations(text, model):
        doc = model(text)
        relations = []

        for token in doc:
            # Check for a subject-verb-object structure
            if token.dep_ in ("nsubj", "nsubjpass") and token.head.pos_ == "VERB":
                subject = token.text
                predicate = token.head.lemma_
                obj = None

                # Look for the object of the verb
                for child in token.head.children:
                    if child.dep_ in ("dobj", "pobj", "attr"):
                        obj = child.text
                        break

                if obj:
                    relations.append({"subject": subject, "predicate": predicate, "object": obj})

        return relations

    # Process each article
    processed_data = []
    for article in articles:
        cleaned_content = clean_text(article["content"])
        entities = extract_entities(cleaned_content, nlp_ner)
        #entities = extract_entities(article["content"], nlp_ner)
        relations = extract_relations(cleaned_content, nlp_re)
        #relations = extract_relations(article["content"], nlp_re)
        processed_data.append({"title": article["title"], "entities": entities, "relations": relations})

    return processed_data


def build_knowledge_graph(processed_data):
    # Define RDF namespace
    EX = Namespace("http://example.org/")
    g = Graph()

    # Helper function to make entity names URI-safe
    def make_uri_safe(name):
        return urllib.parse.quote(name.replace(" ", "_"))

    # Add entities and relations to the graph
    for data in processed_data:
        for entity in data["entities"]:
            entity_name = make_uri_safe(entity["entity"])
            entity_label = make_uri_safe(entity["label"])
            g.add((URIRef(EX[entity_name]), RDF.type, URIRef(EX[entity_label])))

        for relation in data["relations"]:
            subject = make_uri_safe(relation["subject"])
            predicate = make_uri_safe(relation["predicate"])
            obj = make_uri_safe(relation["object"])
            g.add((URIRef(EX[subject]), URIRef(EX[predicate]), URIRef(EX[obj])))

    # Serialize the graph to a Turtle file
    g.serialize("knowledge_graph.ttl", format="turtle")
    print(f"The graph contains {len(g)} triples.")
    return g

# %% [markdown]
# ##### Processing, building graph

# %%
# Process articles
processed_data = process_articles(articles)
# Out:
# C:\Users\rafro\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\spacy\util.py:910: UserWarning: [W095] Model 'en_pipeline' (0.0.0) was trained with spaCy v3.7.5 and may not be 100% compatible with the current version (3.8.4). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Original Text: This video can not be played McIlroy's dramatic Masters triumph Tiger Woods was among the first to congratulate Rory McIlroy on winning the Masters, welcoming him to an exclusive club of men's players to have won golf's Grand Slam. The 35-year-old from Northern Ireland has became only the sixth man and the first European to win the career Grand Slam of Masters, Open Championship, US Open and US PGA Championship titles. Woods, a 15-time major winner, had been the last player to win the Grand Slam in 2000, joining Americans Jack Nicklaus (1966), Ben Hogan (1953), Gene Sarazen (1935) and South Africa's Gary Player (1965). "Welcome to the club," five-time Masters winner Woods wrote on X. "Completing the Grand Slam at Augusta is something special. Your determination during this round, and this entire journey has shown through, and now you're a part of history. Proud of you." McIlroy regrouped from missing a putt which would have secured victory on the 
lroy." Player,at 89 the oldest living member of the now six-strong Grand Slam club, told BBC Radio 5 Live: "I've always said he is the most talented player in the world today. He has the best swing by a mile. "He is a hard worker and he deserves everything he gets. There were two shots in there that I will never forget for as long as I live. "I've never seen such enthusiasm by the crowd. They followed Rory and they wanted him to win. The country can be very proud of him. He is a wonderful, well-mannered man who is doing an awful lot of good for golf." '14 years in the making' - reaction as McIlroy wins Masters to seal career Grand Slam McIlroy beats Rose in Masters play-off to seal career Grand Slam Masters & Slam success will 'free me up' - McIlroy Six key moments that won McIlroy the Masters This video can not be played Watch McIlroy claim his Masters green jacket "I started to wonder if it would ever be my time," said McIlroy, who shot a drama-packed one-over 73 on the final day to tie with Rose on 11 under. "The past 10 years [I've been] coming with the burden of the Grand Slam on my shoulders and trying to achieve that. "I am so proud to be able to call myself a Masters champion. "It's been very difficult. And not just about winning my next major, but the career Grand Slam." McIlroy's travails have been an annual talking point coming into the iconic tournament which takes place every April and is the first of the year's majors. "What are we all going to talk about next year?" McIlroy, with a beaming smile on his face, asked the media after his victory. "It's a dream come true. I have dreamt about that moment for as long as I can remember. "Watching Tiger Woods in 1997, and thenwinning his first Green Jacket,I think that inspired so many of my generation to want to emulate what he did." English veteran Rose, who was also aiming for his Masters victory, courageously fought back to force the play-off with a final-round 66. He had some nice words for his long-time friend McIlroy, before revealing what he told the new Masters champion on the 18th green after the play-off. "I just said, listen, this is a historic moment in golf, isn't it, someone who achieves the career Grand Slam," said Rose. "I said it was pretty cool to be able to share that moment with him. "Obviously I wanted to be the bad guy, but still, it's a momentous occasion for the game of golf." McIlroy's Ryder Cup team-mateShane Lowry,who faded out of contention on Sunday with an 81, told BBC NI Sport: "It's huge for Irish golf. It's huge for everyone. I've h ...
# [{'entity': 'McIlroy', 'label': 'ORG'}, {'entity': 'Tiger Woods', 'label': 'PER'}, {'entity': 'Rory McIlroy', 'label': 'PER'}, {'entity': 'Grand Slam', 'label': 'MISC'}, {'entity': 'Northern Ireland', 'label': 'LOC'}, {'entity': 'European', 'label': 'MISC'}, {'entity': 'Grand Slam', 'label': 'MISC'}, {'entity': 'Open Championship', 'label': 'ORG'}, {'entity': 'US Open', 'label': 'MISC'}, {'entity': 'US', 'label': 'LOC'}, {'entity': 'Woods', 'label': 'PER'}, {'entity': 'Grand Slam', 'label': 'MISC'}, {'entity': 'Americans', 'label': 'MISC'}, {'entity': 'Jack Nicklaus', 'label': 'PER'}, {'entity': 'Ben Hogan', 'label': 'PER'}, {'entity': 'Gene Sarazen', 'label': 'PER'}, {'entity': 'South Africa', 'label': 'LOC'}, {'entity': 'Gary Player', 'label': 'PER'}, {'entity': 'Woods', 'label': 'PER'}, {'entity': 'Grand Slam', 'label': 'MISC'}, {'entity': 'Augusta', 'label': 'LOC'}, {'entity': 'McIlroy', 'label': 'PER'}, {'entity': 'England', 'label': 'LOC'}, {'entity': 'Justin Rose', 'label': 'PER'}, {'entity': 'Augusta National', 'label': 'LOC'}, {'entity': 'US PGA', 'label': 'MISC'}, {'entity': 'Nicklaus,85', 'label': 'LOC'}, {'entity': 'America', 'label': 'LOC'}, {'entity': 'Rory McIlroy', 'label': 'PER'}, {'entity': 'Grand Slam', 'label': 'MISC'}, {'entity': 'BBC Radio', 'label': 'ORG'}, {'entity': 'Rory and they wanted', 'label': 'MISC'}, {'entity': 'McIlroy', 'label': 'ORG'}, {'entity': 'Grand Slam McIlroy', 'label': 'MISC'}, {'entity': 'Rose', 'label': 'PER'}, {'entity': 'Grand Slam Masters', 'label': 'MISC'}, {'entity': 'McIlroy', 'label': 'ORG'}, {'entity': 'McIlroy', 'label': 'ORG'}, {'entity': 'Masters This video', 'label': 'MISC'}, {'entity': 'Watch McIlroy', 'label': 'PER'}, {'entity': 'McIlroy', 'label': 'PER'}, {'entity': 'Rose', 'label': 'LOC'}, {'entity': 'Grand Slam', 'label': 'MISC'}, {'entity': 'Masters', 'label': 'MISC'}, {'entity': 'Grand Slam', 'label': 'MISC'}, {'entity': 'McIlroy', 'label': 'ORG'}, {'entity': 'Tiger Woods', 'label': 'PER'}, {'entity': 'Green Jacket', 'label': 'PER'}, {'entity': 'English', 'label': 'MISC'}, {'entity': 'Rose', 'label': 'PER'}, {'entity': 'McIlroy', 'label': 'PER'}, {'entity': 'Grand Slam', 'label': 'MISC'}, {'entity': 'Rose', 'label': 'PER'}, {'entity': "McIlroy's", 'label': 'ORG'}, {'entity': 'Ryder Cup', 'label': 'MISC'}, {'entity': 'Lowry', 'label': 'PER'}, {'entity': 'BBC NI Sport', 'label': 'ORG'}, {'entity': 'Irish', 'label': 'MISC'}, {'entity': 'Lowry', 'label': 'PER'}, {'entity': 'Ireland', 'label': 'LOC'}, {'entity': 'Open', 'label': 'MISC'}, {'entity': 'Green Jacket', 'label': 'PER'}, {'entity': "England'sTommy Fleetwoodsaid", 'label': 'MISC'}, {'entity': 'Rory McIlroy', 'label': 'PER'}, {'entity': 'Northern Ireland', 'label': 'ORG'}, {'entity': 'Open', 'label': 'MISC'}, {'entity': 'Ryder Cup', 'label': 'MISC'}, {'entity': 'Harry', 'label': 'PER'}, {'entity': 'Diamond', 'label': 'ORG'}, {'entity': 'McIlroy', 'label': 'ORG'}, {'entity': 'Bryson DeChambeau', 'label': 'PER'}, {'entity': 'American', 'label': 'MISC'}, {'entity': 'McIlroy', 'label': 'PER'}, {'entity': 'US Open', 'label': 'MISC'}, {'entity': 'McIlroy', 'label': 'LOC'}, {'entity': 'DeChambeau', 'label': 'PER'}, {'entity': 'PGA Tour', 'label': 'MISC'}, {'entity': 'LIV Golf', 'label': 'ORG'}, {'entity': 'McIlroy', 'label': 'PER'}, {'entity': 'DeChambeau', 'label': 'PER'}, {'entity': 'McIlroy', 'label': 'PER'}, {'entity': 'McIlroy', 'label': 'ORG'}, {'entity': 'Grand Slam McIlroy', 'label': 'MISC'}, {'entity': 'Harry Diamond', 'label': 'PER'}, {'entity': 'Diamond', 'label': 'PER'}, {'entity': 'McIlroy’s', 'label': 'ORG'}, {'entity': 'JP Fitzgerald', 'label': 'PER'}, {'entity': 'McIlroy', 'label': 'PER'}, {'entity': 'Harry', 'label': 'PER'}, {'entity': 'Holywood Golf Club', 'label': 'LOC'}, {'entity': 'McIlroy', 'label': 'PER'}, {'entity': 'Diamond', 'label': 'PER'}, {'entity': 'Harry', 'label': 'PER'}, {'entity': 'McIlroy', 'label': 'PER'}, {'entity': 'McIlroy Podcast', 'label': 'LOC'}, {'entity': 'Rory McIlroy', 'la ...
# Original Text: Luka Modric won the Ballon d'Or in 2018 and has six Champions League titles to his name Real Madrid and Croatia legend Luka Modric is set to take a minority ownership stake in Swansea City. The 39-year-old midfielder is to join Andy Coleman, Brett Cravatt, Nigel Morris and Jason Cohen among the ownership group. That cohortpurchased the shares of former majority owners Jason Levien and Steve Kaplanlast November. Modric's move is believed to be his first into football ownership and he will continue to play for Real Madrid, albeit with his current contract due to expire at the end of the 2024-25 season. Swansea post pre-tax loss of £15.2m Modric signs one-year extension with Real Madrid Latest Swansea City news, analysis and fan views Luka Modric, then of Tottenham Hotspur, competes for the ball with Joe Allen in 2012 when Swansea City were in the Premier League - Allen is in his second stint at Swansea while Modric is a veteran at Real Madrid Modric will be involved at a Championship club which posted a pre-tax loss of £15.2m in the latest financial year. That was a drop of £2.7m compared to the pre-tax loss of £17.9m posted for the previous financial year. Swansea posted a turnover of £21.5m for the year ending 30 June, 2024. In a statement accompanying their annual financial status, Swansea said: "The board acknowledges that whilst the magnitude of the operational loss is a product of the highly competitive environment within the EFL Championship in which the club currently competes, the club will continue to focus on achieving operational efficiencies in order to maximise the resources which can be invested into the first-team squad. "The costs of operating a stadium and two
tributes to McIlroy Modric to become Swansea minority owner The Doctor and Belinda embark on an intergalactic journey home Directed by Sam Mendes, the true story of WW2 soldier-cameramen The final five face the toughest interviews of their lives The acclaimed Australian thriller returns with a new twist How coping with 'heartbreak' changed everything for McIlroy McIlroy's dramatic Masters triumph. VideoMcIlroy's dramatic Masters triumph Corner chicken & Rory Delap 2.0 - what's the future of football? Six key moments that won McIlroy the Masters Can Swiatek emulate Alcaraz to start clay season? McIlroy's emotional message to daughter Poppy. VideoMcIlroy's emotional message to daughter Poppy Bayindir's failed Man Utd audition offers Onana dilemma Are record-equalling Hibs Scotland's third force? Rory McIlroy completes career Grand Slam with Masters victory. AudioRory McIlroy completes career Grand Slam with Masters victory 'We had to put a smile on his face' - Newcastle dedicate win to Howe What's gone wrong for Man City in trophyless season? 'No-one can do what Kevin has' - De Bruyne shines as Man City exit nears Dominant Pimblett stops Chandler for biggest UFC win 'Calm' England have 'great capacity' to regroup 142 unanswered points - who can stop Leinster in Europe? Has 'micro-managed' Premier League become boring? Why Salah turned down '£500m Saudi move' for Liverpool stay Explainer: Semi-automated offsides start in Premier League The rise and poignant fall of Wrexham Deadpool hero Mullin 'He's the chosen one!' - the rise of Lamine Yamal. Video'He's the chosen one!' - the rise of Lamine Yamal Copyright © 2025 BBC. The BBC is not responsible for the content of external sites.Read about our approach to external linking.
# [{'entity': 'Luka Modric', 'label': 'PER'}, {'entity': 'Ballon', 'label': 'ORG'}, {'entity': 'Real Madrid', 'label': 'ORG'}, {'entity': 'Croatia', 'label': 'LOC'}, {'entity': 'Luka Modric', 'label': 'PER'}, {'entity': 'Swansea City', 'label': 'LOC'}, {'entity': 'Andy Coleman', 'label': 'PER'}, {'entity': 'Brett Cravatt', 'label': 'PER'}, {'entity': 'Nigel Morris', 'label': 'PER'}, {'entity': 'Jason Cohen', 'label': 'PER'}, {'entity': 'Jason Levien', 'label': 'PER'}, {'entity': 'Steve Kaplanlast', 'label': 'PER'}, {'entity': 'Modric', 'label': 'PER'}, {'entity': 'Real Madrid', 'label': 'ORG'}, {'entity': 'Modric', 'label': 'PER'}, {'entity': 'Real Madrid', 'label': 'ORG'}, {'entity': 'Swansea City', 'label': 'ORG'}, {'entity': 'Luka Modric', 'label': 'PER'}, {'entity': 'Tottenham Hotspur', 'label': 'PER'}, {'entity': 'Joe Allen', 'label': 'PER'}, {'entity': 'Swansea City', 'label': 'PER'}, {'entity': 'Allen', 'label': 'PER'}, {'entity': 'Swansea', 'label': 'LOC'}, {'entity': 'Modric', 'label': 'PER'}, {'entity': 'Real Madrid Modric', 'label': 'ORG'}, {'entity': 'Swansea', 'label': 'PER'}, {'entity': 'Swansea', 'label': 'PER'}, {'entity': 'EFL Championship', 'label': 'ORG'}, {'entity': 'EFL', 'label': 'ORG'}, {'entity': 'Premier League', 'label': 'MISC'}, {'entity': 'Comments', 'label': 'ORG'}, {'entity': 'JavaScript', 'label': 'PER'}, {'entity': 'Marko', 'label': 'PER'}, {'entity': 'McIlroy Modric', 'label': 'LOC'}, {'entity': 'Swansea', 'label': 'ORG'}, {'entity': 'Belinda', 'label': 'ORG'}, {'entity': 'Directed', 'label': 'PER'}, {'entity': 'Sam Mendes', 'label': 'PER'}, {'entity': 'Australian', 'label': 'MISC'}, {'entity': 'McIlroy McIlroy', 'label': 'PER'}, {'entity': 'VideoMcIlroy', 'label': 'ORG'}, {'entity': 'Corner', 'label': 'PER'}, {'entity': 'Delap', 'label': 'ORG'}, {'entity': 'McIlroy', 'label': 'ORG'}, {'entity': 'Masters Can Swiatek', 'label': 'ORG'}, {'entity': 'Alcaraz', 'label': 'ORG'}, {'entity': 'McIlroy', 'label': 'PER'}, {'entity': 'Poppy', 'label': 'PER'}, {'entity': 'VideoMcIlroy', 'label': 'ORG'}, {'entity': 'Poppy Bayindir', 'label': 'PER'}, {'entity': 'Man Utd', 'label': 'MISC'}, {'entity': 'Onana', 'label': 'LOC'}, {'entity': 'Hibs Scotland', 'label': 'PER'}, {'entity': 'Rory McIlroy', 'label': 'PER'}, {'entity': 'Grand Slam', 'label': 'MISC'}, {'entity': 'AudioRory McIlroy', 'label': 'PER'}, {'entity': 'Grand Slam', 'label': 'MISC'}, {'entity': 'Newcastle', 'label': 'ORG'}, {'entity': "Howe What's", 'label': 'MISC'}, {'entity': 'Man City', 'label': 'LOC'}, {'entity': 'Kevin', 'label': 'PER'}, {'entity': 'De Bruyne', 'label': 'PER'}, {'entity': 'Dominant Pimblett', 'label': 'PER'}, {'entity': 'Chandler', 'label': 'PER'}, {'entity': 'UFC', 'label': 'ORG'}, {'entity': 'England', 'label': 'LOC'}, {'entity': 'Leinster', 'label': 'ORG'}, {'entity': 'Europe', 'label': 'LOC'}, {'entity': 'Salah', 'label': 'PER'}, {'entity': 'Saudi', 'label': 'MISC'}, {'entity': 'Liverpool', 'label': 'ORG'}, {'entity': 'Explainer', 'label': 'PER'}, {'entity': 'Semi', 'label': 'PER'}, {'entity': 'Premier League The', 'label': 'MISC'}, {'entity': 'Wrexham Deadpool', 'label': 'MISC'}, {'entity': 'Mullin', 'label': 'LOC'}, {'entity': 'Lamine Yamal', 'label': 'MISC'}, {'entity': 'Lamine Yamal Copyright', 'label': 'ORG'}]
# Original Text: Corner chicken & Rory Delap 2.0 - what's the future of football? If the past decade of English football has one unifying theme it is tactical renewal. Since the mid-2010s - and since Antonio Conte, Pep Guardiola and Jurgen Klopp - the Premier League has attracted Europe's best coaches, putting a once sleepy and unsophisticated division at the vanguard of tactical innovation. But we are in a moment of flux. New ideas still flood into the league but nothing, yet, has emerged as the next great theory. As Guardiola treads water at Manchester City we are waiting to find out where the sport goes next. Here are some ideas - some quirkier than others - for the future of football. Premier League intensity or caution - how will Tuchel's England play? Why Guardiola's tactics stopped working amid rise of rapid football Embracing the chaos - breaking down Bournemouth's rise Let's start with one of the weirder ones… but also one that feeds most directly into where the game seems to be heading. A couple of years ago the way Roberto de Zerbi stretched the pitch from goal-kicks was all the rage. He kept five players next to his goalkeeper and stuck five players on the halfway line, emptying central midfield and splitting a confused opposition in two. Brighton would then kick it long, bypassing half the team. This kind of thing might come back again, and certainly long balls are boomeranging back into fashion as the natural antidote to high pressing, short goal-kicks and high defensive lines. A decade of sucking everyone into tight spaces was bound to trigger a counter-reaction of stretching things back out. So, here's a thought for all those high-risk De Zerbi types. When defending a corner, instead of packing the box with bodies, why not begin a game of chicken and leave four or five on the halfway line? This would create exciting five-on-two long-ball counter-attacking scenarios, or, more likely, force the attacking team to leave five or six players back. Just like that you've decluttered the penalty area and, at the elite level, clearing a path for the goalkeeper and creating simpler one-on-one marking could reduce the chances of conceding. Corners are in vogue at the moment and the set-piece coach is the new must-have accessory. But maybe we're looking too closely at 'love trains' and marking systems in a messy penalty box. It's within a team's power to free up space and lean into ultra-stretched football. Just don't be chicken. There isn't enough deception in football tactics. There are the 'dark arts' of defending, the dummy and the no-look pass. But where are the Trojan horses, the tactical decoys? Players are getting more versatile all the time and (most) managers are too, regularly changing formation between matches and within them. In fact, a lot of managers these days would reject the idea of the formation. But there are still basic differences between, say, the 4-3-3 and the 3-4-2-1, and although a lot of coaches are comfortable switching it up based on the game state - moving to a back three to see out the final few minutes of a 1-0 lead, for example - nobody changes formation early in a game. And nobody is doing it to fool the other manager. Imagine two teams lining up in similar 4-3-3s, with touchline-hugging wingers and two number eights in front of a defensive midfielder. For the first 10 minutes they feel each other out, getting used to their opponents' patterns. Then all of a sudden one team swaps to a 3-4-2-1. The wingers disappear, the three-player triangle in midfield becomes a box-shape four, and the other side has to scramble to keep up. Five minutes later, they change back again. Or switch to a third system entirely. It would be chaotic, but the team who planned the switches in training would have a huge advantage in those frantic few minutes of adaptation. And it could have a huge impact on the game because, at the risk of getting highfalutin, it would require a new way of thinking about time. Currently ...
# Cleaned Text: Corner chicken & Rory Delap 2.0 - what's the future of football? If the past decade of English football has one unifying theme it is tactical renewal. Since the mid-2010s - and since Antonio Conte, Pep Guardiola and Jurgen Klopp - the Premier League has attracted Europe's best coaches, putting a once sleepy and unsophisticated division at the vanguard of tactical innovation. But we are in a moment of flux. New ideas still flood into the league but nothing, yet, has emerged as the next great theory. As Guardiola treads water at Manchester City we are waiting to find out where the sport goes next. Here are some ideas - some quirkier than others - for the future of football. Premier League intensity or caution - how will Tuchel's England play? Why Guardiola's tactics stopped working amid rise of rapid football Embracing the chaos - breaking down Bournemouth's rise Let's start with one of the weirder ones… but also one that feeds most directly into where the game seems to be heading. A couple of years ago the way Roberto de Zerbi stretched the pitch from goal-kicks was all the rage. He kept five players next to his goalkeeper and stuck five players on the halfway line, emptying central midfield and splitting a confused opposition in two. Brighton would then kick it long, bypassing half the team. This kind of thing might come back again, and certainly long balls are boomeranging back into fashion as the natural antidote to high pressing, short goal-kicks and high defensive lines. A decade of sucking everyone into tight spaces was bound to trigger a counter-reaction of stretching things back out. So, here's a thought for all those high-risk De Zerbi types. When defending a corner, instead of packing the box with bodies, why not begin a game of chicken and leave four or five on the halfway line? This would create exciting five-on-two long-ball counter-attacking scenarios, or, more likely, force the attacking team to leave five or six players back. Just like that you've decluttered the penalty area and, at the elite level, clearing a path for the goalkeeper and creating simpler one-on-one marking could reduce the chances of conceding. Corners are in vogue at the moment and the set-piece coach is the new must-have accessory. But maybe we're looking too closely at 'love trains' and marking systems in a messy penalty box. It's within a team's power to free up space and lean into ultra-stretched football. Just don't be chicken. There isn't enough deception in football tactics. There are the 'dark arts' of defending, the dummy and the no-look pass. But where are the Trojan horses, the tactical decoys? Players are getting more versatile all the time and (most) managers are too, regularly changing formation between matches and within them. In fact, a lot of managers these days would reject the idea of the formation. But there are still basic differences between, say, the 4-3-3 and the 3-4-2-1, and although a lot of coaches are comfortable switching it up based on the game state - moving to a back three to see out the final few minutes of a 1-0 lead, for example - nobody changes formation early in a game. And nobody is doing it to fool the other manager. Imagine two teams lining up in similar 4-3-3s, with touchline-hugging wingers and two number eights in front of a defensive midfielder. For the first 10 minutes they feel each other out, getting used to their opponents' patterns. Then all of a sudden one team swaps to a 3-4-2-1. The wingers disappear, the three-player triangle in midfield becomes a box-shape four, and the other side has to scramble to keep up. Five minutes later, they change back again. Or switch to a third system entirely. It would be chaotic, but the team who planned the switches in training would have a huge advantage in those frantic few minutes of adaptation. And it could have a huge impact on the game because, at the risk of getting highfalutin, it would require a new way of thinking about time. Currently  ...
# [{'entity': 'Corner', 'label': 'PER'}, {'entity': 'Delap', 'label': 'ORG'}, {'entity': 'English', 'label': 'MISC'}, {'entity': 'mid-2010s', 'label': 'MISC'}, {'entity': 'Antonio Conte', 'label': 'PER'}, {'entity': 'Pep Guardiola', 'label': 'PER'}, {'entity': 'Jurgen Klopp', 'label': 'PER'}, {'entity': 'Europe', 'label': 'LOC'}, {'entity': 'Guardiola', 'label': 'PER'}, {'entity': 'Manchester City', 'label': 'LOC'}, {'entity': 'Tuchel', 'label': 'PER'}, {'entity': 'England', 'label': 'LOC'}, {'entity': 'Why Guardiola', 'label': 'PER'}, {'entity': 'Bournemouth', 'label': 'ORG'}, {'entity': 'Let', 'label': 'ORG'}, {'entity': 'Roberto de Zerbi', 'label': 'PER'}, {'entity': 'Brighton', 'label': 'ORG'}, {'entity': 'De Zerbi', 'label': 'PER'}, {'entity': 'Trojan', 'label': 'LOC'}, {'entity': 'Or', 'label': 'LOC'}, {'entity': 'Time', 'label': 'PER'}, {'entity': 'Premier League', 'label': 'MISC'}, {'entity': 'Except', 'label': 'PER'}, {'entity': 'Delap', 'label': 'PER'}, {'entity': 'Stoke City', 'label': 'ORG'}, {'entity': 'Hull City', 'label': 'PER'}, {'entity': 'Boaz Myhill', 'label': 'PER'}, {'entity': 'Delap', 'label': 'PER'}, {'entity': 'Delap', 'label': 'PER'}, {'entity': 'Delap', 'label': 'PER'}, {'entity': 'Mikel Arteta', 'label': 'PER'}, {'entity': 'Tony Pulis', 'label': 'PER'}, {'entity': 'Stoke', 'label': 'PER'}, {'entity': 'Delap', 'label': 'PER'}, {'entity': 'Rick Barry', 'label': 'PER'}, {'entity': 'Barry', 'label': 'PER'}, {'entity': 'NBA', 'label': 'ORG'}, {'entity': "Shaquille O'Neal", 'label': 'PER'}, {'entity': 'Barry', 'label': 'PER'}, {'entity': 'Delap', 'label': 'ORG'}, {'entity': 'Chris Wilder', 'label': 'PER'}, {'entity': 'Sheffield United', 'label': 'LOC'}, {'entity': 'England', 'label': 'LOC'}, {'entity': 'Thomas Tuchel', 'label': 'PER'}, {'entity': 'Ange Postecoglou', 'label': 'LOC'}, {'entity': 'Franco Baresi', 'label': 'PER'}, {'entity': 'England Rio Ferdinand', 'label': 'LOC'}, {'entity': 'Destiny Udogie', 'label': 'ORG'}, {'entity': 'Tottenham Hotspur', 'label': 'LOC'}, {'entity': 'Harry Kane', 'label': 'PER'}, {'entity': 'OK', 'label': 'ORG'}, {'entity': 'Liverpool', 'label': 'ORG'}, {'entity': 'League One', 'label': 'MISC'}, {'entity': 'EFL Cup', 'label': 'MISC'}, {'entity': 'Goalkeeper Alisson', 'label': 'PER'}, {'entity': 'Arne Slot', 'label': 'PER'}, {'entity': 'Alisson', 'label': 'PER'}, {'entity': 'Arnold', 'label': 'LOC'}, {'entity': 'Trent', 'label': 'PER'}, {'entity': 'Alexander', 'label': 'LOC'}, {'entity': 'Arnold', 'label': 'LOC'}, {'entity': 'Liverpool', 'label': 'ORG'}, {'entity': 'Alexander', 'label': 'LOC'}, {'entity': 'Arnold', 'label': 'LOC'}, {'entity': 'Football Daily', 'label': 'PER'}, {'entity': 'Get', 'label': 'ORG'}, {'entity': 'Comments', 'label': 'ORG'}, {'entity': 'Comments', 'label': 'ORG'}, {'entity': 'JavaScript', 'label': 'PER'}]
# Original Text: In the latest edition of Second Serve, our new weekly snapshot of the tours, BBC senior journalist Amy Lofthouse looks at how the start of the clay-court season has unfolded. Iga Swiatek is set for a mammoth few months. The world number two is defending 4,195 points during the clay-court season after her astonishing 2024, which saw her win every tournament on the surface bar the Stuttgart Open. Even then, she reached the semi-finals. Poland's Swiatek won both WTA 1,000 titles in Madrid and Italy, before picking up another 2,000 points from defending her French Open title. Simply put, she's defending 54% of her 7,276 points over the next six weeks - and world number three Jessica Pegula, breathing down her neck, is defending none. Clay is Swiatek's best surface, the slower conditions giving her more time on her pacey forehand, backed up by her superb movement around the court. But it's been a tricky year for Swiatek. She lost in the Australian Open semi-finals from match point up, wasstunned at the Miami Openby Filipina teenager Alexandra Eala and has cut a stressed, irritable figure on court. Swiatek has also had to deal with an upsetting incident off the court, beingverbally abusedby an "aggressive and taunting fan" in Miami. A return to her favoured clay might provide a reset for her - as Carlos Alcaraz has shown. Like Swiatek, Alcaraz is the defending French Open champion. He too has had a mixed start to the year. He too had a surprise loss in Miami and, like Swiatek, has a tendency to be overly self-critical. The new Monte Carlo champion did not have it all his own way on his run to the title. His quarter-final against Arthur Fils was a tricky, tight encounter, and the Spaniard was second-best in the early stages of the final against Lorenzo Musetti. But Alcaraz found a way through and, ultimately, a way to win. That is something Swiatek can emulate this week in Stuttgart and beyond. Katie Boulter and Jodie Burrage teamed up ina brilliant doubles performanceto secure Great Britain's place in September's Billie Jean King Cup Finals. Emma Raducanuis in talkswith former player turned commentator Mark Petchy about appointing him as her new coach. The legendary Billie Jean Kingreceived a staron the Hollywood Walk of Fame. There has been very little movement on the WTA side, with players either practising or competing at the Billie Jean King Cup, which does not offer ranking points. On the men's side,Lorenzo Musetti'sMonte Carlo run has left him knocking on the door of the world's top 10. Owner of a one-handed backhand - one of the most beautiful sights in tennis - Musetti beat defending champion Stefanos Tsitsipas and 10th-ranked Alex de Minaur to reach the final. He will be hoping the thigh injury that hampered him against Alcaraz will not hold up his clay season too much. The Stuttgart Open, where the winner wal
va. Former US Open championBianca Andreescu, who has been plagued by injury since her 2019 win, is set to make her first appearance of the year at the Open de Rouen in France. On the men's side, Alcaraz heads up the Barcelona Open field, alongside defending championCasper RuudandAndrey Rublev,whileAlexander Zverevis top seed at the Munich Open. British doubles pairJulian Cash and Lloyd Glasspoolbegan their clay swing strongly, reaching the final of the Monte Carlo Masters. The duo won the first set but ultimately fell 1-6 7-6 (10-8) 10-8 to home favourite Romain Arneodo and France's Manuel Guinard. Henry Pattenand Finnish partner Harri Heliovaara also reached the semi-finals in Monaco, losing to the eventual champions, whileGiles Husseytriumphed at the ITF M15 in Monastir. Sonay Kartal, fresh from her impressive BJK Cup debut, is the eighth seed at the Open de Rouen, withHarriet Dartalso competing. Cameron Norriecame through qualifying to rea ...
# [{'entity': 'Second Serve', 'label': 'PER'}, {'entity': 'BBC', 'label': 'ORG'}, {'entity': 'Amy Lofthouse', 'label': 'PER'}, {'entity': 'Iga Swiatek', 'label': 'ORG'}, {'entity': 'Stuttgart Open', 'label': 'MISC'}, {'entity': 'Poland', 'label': 'LOC'}, {'entity': 'WTA', 'label': 'ORG'}, {'entity': 'Madrid', 'label': 'LOC'}, {'entity': 'Italy', 'label': 'LOC'}, {'entity': 'French Open', 'label': 'MISC'}, {'entity': 'Jessica Pegula', 'label': 'PER'}, {'entity': 'Clay', 'label': 'PER'}, {'entity': 'Australian Open', 'label': 'MISC'}, {'entity': 'Miami Openby Filipina', 'label': 'ORG'}, {'entity': 'Alexandra Eala', 'label': 'PER'}, {'entity': 'Swiatek', 'label': 'PER'}, {'entity': 'Miami', 'label': 'LOC'}, {'entity': 'Carlos Alcaraz', 'label': 'PER'}, {'entity': 'Alcaraz', 'label': 'ORG'}, {'entity': 'French Open', 'label': 'MISC'}, {'entity': 'Miami', 'label': 'LOC'}, {'entity': 'Swiatek', 'label': 'PER'}, {'entity': 'Monte Carlo', 'label': 'LOC'}, {'entity': 'Arthur Fils', 'label': 'LOC'}, {'entity': 'Spaniard', 'label': 'MISC'}, {'entity': 'Lorenzo Musetti', 'label': 'PER'}, {'entity': 'Alcaraz', 'label': 'ORG'}, {'entity': 'Swiatek', 'label': 'PER'}, {'entity': 'Stuttgart', 'label': 'LOC'}, {'entity': 'Katie Boulter', 'label': 'PER'}, {'entity': 'Jodie Burrage', 'label': 'PER'}, {'entity': 'Great Britain', 'label': 'PER'}, {'entity': 'Billie Jean', 'label': 'PER'}, {'entity': 'Emma Raducanuis', 'label': 'PER'}, {'entity': 'Mark Petchy', 'label': 'PER'}, {'entity': 'Billie Jean Kingreceived', 'label': 'PER'}, {'entity': 'Hollywood Walk of Fame', 'label': 'ORG'}, {'entity': 'WTA', 'label': 'ORG'}, {'entity': 'Billie Jean King Cup', 'label': 'MISC'}, {'entity': "Lorenzo Musetti'sMonte Carlo", 'label': 'PER'}, {'entity': 'Musetti', 'label': 'PER'}, {'entity': 'Stefanos Tsitsipas', 'label': 'PER'}, {'entity': 'Alex de Minaur', 'label': 'PER'}, {'entity': 'Alcaraz', 'label': 'ORG'}, {'entity': 'Stuttgart Open', 'label': 'MISC'}, {'entity': 'Porsche', 'label': 'ORG'}, {'entity': 'WTA Tour', 'label': 'MISC'}, {'entity': 'includingAryna Sabalenka', 'label': 'ORG'}, {'entity': 'Jessica PegulaandMirra', 'label': 'PER'}, {'entity': 'US Open', 'label': 'MISC'}, {'entity': 'Andreescu', 'label': 'LOC'}, {'entity': 'Open de Rouen', 'label': 'MISC'}, {'entity': 'France', 'label': 'LOC'}, {'entity': 'Alcaraz', 'label': 'ORG'}, {'entity': 'Barcelona Open', 'label': 'MISC'}, {'entity': 'RuudandAndrey Rublev', 'label': 'PER'}, {'entity': 'whileAlexander Zverevis', 'label': 'PER'}, {'entity': 'Munich Open', 'label': 'MISC'}, {'entity': 'British', 'label': 'MISC'}, {'entity': 'Lloyd Glasspoolbegan', 'label': 'PER'}, {'entity': 'Monte Carlo Masters', 'label': 'ORG'}, {'entity': 'Romain Arneodo', 'label': 'PER'}, {'entity': 'France', 'label': 'LOC'}, {'entity': 'Manuel Guinard', 'label': 'PER'}, {'entity': 'Finnish', 'label': 'MISC'}, {'entity': 'Harri Heliovaara', 'label': 'PER'}, {'entity': 'Monaco', 'label': 'LOC'}, {'entity': 'whileGiles Husseytriumphed', 'label': 'PER'}, {'entity': 'ITF M15', 'label': 'ORG'}, {'entity': 'Monastir', 'label': 'PER'}, {'entity': 'Sonay Kartal', 'label': 'PER'}, {'entity': 'BJK Cup', 'label': 'MISC'}, {'entity': 'Open de Rouen', 'label': 'MISC'}, {'entity': 'Dartalso', 'label': 'PER'}, {'entity': 'Cameron Norriecame', 'label': 'PER'}, {'entity': 'Barcelona', 'label': 'LOC'}, {'entity': 'Jacob Fearnleylost', 'label': 'PER'}, {'entity': 'Harrisin Munich', 'label': 'PER'}, {'entity': 'Lucy ShukerandBen Bartramare', 'label': 'PER'}, {'entity': 'Japan Open', 'label': 'MISC'}, {'entity': 'BBC Sport', 'label': 'ORG'}, {'entity': 'Second Serve', 'label': 'PER'}, {'entity': 'ATP', 'label': 'ORG'}, {'entity': 'WTA', 'label': 'ORG'}, {'entity': 'British', 'label': 'MISC'}, {'entity': 'BBC Sport', 'label': 'ORG'}, {'entity': 'Comments', 'label': 'ORG'}, {'entity': 'JavaScript', 'label': 'PER'}, {'entity': 'Marko', 'label': 'PER'}, {'entity': 'McIlroy Modric', 'label': 'LOC'}, {'entity': 'Swansea', 'label': 'ORG'}, {'entity': 'Be ...
# ...
# Original Text: This video can not be played Man Utd goalkeeper conundrum a 'huge problem' - Murphy It was the last thing Manchester United manager Ruben Amorim needed. After taking goalkeeper Andre Onana out of the firing line for Sunday's trip to Newcastle, the Portuguese watched forlorn as replacement Altay Bayindir conceded four goals in achastening defeat at St James' Park. To makes matters worse, the Turkey international was to blame for Newcastle's fourth after a poor pass. "We did a lot of mistakes that made it harder to win a game - that's all," said Amorim. "It's a little bit of everything, it's hard to point to one thing." With a crucial Europa League quarter-final second leg to follow against Lyon on Thursday, United are keen to put defeat in the north-east quickly behind them. But Amorim now faces a potentially season-defining decision of whether to
for it, so it's a big call for the manager." Onana came under fire again following two costly errors in the 2-2 first-leg draw in Lyon last Thursday. Since the start of last season, the 29-year-old has made eight errors leading to goals in all competitions, the most of any keeper playing for a Premier League club. "The situation has been coming," former England goalkeeper Paul Robinson told 5 Live. "A lot of Manchester United fans have been getting frustrated with him and there is a time where you do need to take the goalkeeper out of the firing line because the pressure does become too much. "When you're in front of the opposition fans, you're reminded of your poor form every time you touch the ball and sometimes you do need a rest. "It's good man-management to put your arm round him and say, 'look you're still my number one goalkeeper, but at the moment you're not playing to the levels I want you to play at - I'm going to take you out, whether it's one, two or three games'." Newcastle beat Man Utd to boost Champions League hopes How does Onana compare to other Man Utd keepers after Matic criticism? Ruben Amorim’s Manchester United goalkeeping dilemma Amorim may have been keen to stress Onana's omission was a one-game decision, but you don't drop your first-choice keeper at this stage of the season and do so lightly. Bayindir, a £4.3m signing from Fenerbahce in 2023, has waited patiently for his first start in the Premier League. But the 26-year-old failed to grasp his opportunity against Newcastle, conceding four of Newcastle's six shots on target and flapping at a number of crosses. He attempted 57 passes, but completed just 27 of those - an unimpressive rate of 47.4%. The most costly of those passes came 13 minutes from time, when Bayindir attempted a chipped pass into midfield that was cut out by Joelinton, allowing Bruno Guimaraes to add a fourth goal. Newcastle were already on their way to victory by then, but the passage of play underlined why, even with Onana making so many errors, Amorim has tended to keep faith with the former Inter Milan stopper. Amorim, understandably, was keen to move on from the defeat by Newcastle and stressed several times in his post-match interview how the focus was now firmly on the visit of Lyon. It's the biggest match of his United reign so far, keeping hopes alive of a trophy and place in next season's Champions League, but the Portuguese was giving nothing away when asked if he would recall Onana. "You have to wait, we are going to start the next we ...
# [{'entity': 'Man Utd', 'label': 'MISC'}, {'entity': 'Murphy It', 'label': 'PER'}, {'entity': 'Manchester United', 'label': 'ORG'}, {'entity': 'Ruben Amorim', 'label': 'PER'}, {'entity': 'Andre Onana', 'label': 'PER'}, {'entity': 'Newcastle', 'label': 'ORG'}, {'entity': 'Portuguese', 'label': 'MISC'}, {'entity': 'Altay Bayindir', 'label': 'PER'}, {'entity': 'St James', 'label': 'LOC'}, {'entity': 'Turkey', 'label': 'LOC'}, {'entity': 'Newcastle', 'label': 'ORG'}, {'entity': 'Amorim', 'label': 'PER'}, {'entity': 'Europa League', 'label': 'MISC'}, {'entity': 'Lyon', 'label': 'ORG'}, {'entity': 'United', 'label': 'ORG'}, {'entity': 'Amorim', 'label': 'ORG'}, {'entity': 'Onana', 'label': 'LOC'}, {'entity': 'Bayindir', 'label': 'LOC'}, {'entity': 'Altay Bayindir', 'label': 'PER'}, {'entity': 'Newcastle', 'label': 'ORG'}, {'entity': 'Onana', 'label': 'LOC'}, {'entity': 'Newcastle', 'label': 'ORG'}, {'entity': 'United', 'label': 'ORG'}, {'entity': 'Manchester United', 'label': 'ORG'}, {'entity': 'Roy Keane', 'label': 'PER'}, {'entity': 'Amorim', 'label': 'ORG'}, {'entity': 'Cameroon', 'label': 'LOC'}, {'entity': 'Onana', 'label': 'LOC'}, {'entity': 'OK', 'label': 'ORG'}, {'entity': 'Premier League', 'label': 'MISC'}, {'entity': 'United', 'label': 'ORG'}, {'entity': 'Keane', 'label': 'PER'}, {'entity': 'Sky Sports', 'label': 'ORG'}, {'entity': 'Onana', 'label': 'PER'}, {'entity': 'Lyon', 'label': 'ORG'}, {'entity': 'Premier League', 'label': 'MISC'}, {'entity': 'England', 'label': 'LOC'}, {'entity': 'Paul Robinson', 'label': 'PER'}, {'entity': 'Live', 'label': 'ORG'}, {'entity': 'Manchester United', 'label': 'ORG'}, {'entity': 'Newcastle', 'label': 'ORG'}, {'entity': 'Man Utd', 'label': 'PER'}, {'entity': 'Onana', 'label': 'LOC'}, {'entity': 'Man Utd', 'label': 'MISC'}, {'entity': 'Matic', 'label': 'MISC'}, {'entity': 'Ruben Amorim', 'label': 'PER'}, {'entity': 'Manchester United', 'label': 'ORG'}, {'entity': 'Amorim', 'label': 'ORG'}, {'entity': 'Onana', 'label': 'LOC'}, {'entity': 'Bayindir', 'label': 'PER'}, {'entity': 'Fenerbahce', 'label': 'ORG'}, {'entity': 'Premier League', 'label': 'MISC'}, {'entity': 'Newcastle', 'label': 'ORG'}, {'entity': 'Newcastle', 'label': 'ORG'}, {'entity': 'Bayindir', 'label': 'PER'}, {'entity': 'Joelinton', 'label': 'PER'}, {'entity': 'Bruno Guimaraes', 'label': 'PER'}, {'entity': 'Newcastle', 'label': 'ORG'}, {'entity': 'Onana', 'label': 'LOC'}, {'entity': 'Amorim', 'label': 'ORG'}, {'entity': 'Inter Milan', 'label': 'ORG'}, {'entity': 'Newcastle', 'label': 'ORG'}, {'entity': 'Lyon', 'label': 'ORG'}, {'entity': 'United', 'label': 'ORG'}, {'entity': 'Champions League', 'label': 'MISC'}, {'entity': 'Portuguese', 'label': 'MISC'}, {'entity': 'Onana', 'label': 'PER'}, {'entity': 'Amorim', 'label': 'PER'}, {'entity': 'Onana', 'label': 'LOC'}, {'entity': 'Lyon', 'label': 'ORG'}, {'entity': 'Tottenham', 'label': 'ORG'}, {'entity': 'Manchester United', 'label': 'ORG'}, {'entity': 'Get Man Utd', 'label': 'ORG'}, {'entity': 'Marko', 'label': 'PER'}, {'entity': 'McIlroy Modric', 'label': 'LOC'}, {'entity': 'Swansea', 'label': 'ORG'}, {'entity': 'Belinda', 'label': 'ORG'}, {'entity': 'Directed', 'label': 'PER'}, {'entity': 'Sam Mendes', 'label': 'PER'}, {'entity': 'Australian', 'label': 'MISC'}, {'entity': 'McIlroy McIlroy', 'label': 'PER'}, {'entity': 'VideoMcIlroy', 'label': 'ORG'}, {'entity': 'Corner', 'label': 'PER'}, {'entity': 'Delap', 'label': 'ORG'}, {'entity': 'McIlroy', 'label': 'ORG'}, {'entity': 'Masters Can Swiatek', 'label': 'ORG'}, {'entity': 'Alcaraz', 'label': 'ORG'}, {'entity': 'McIlroy', 'label': 'PER'}, {'entity': 'Poppy', 'label': 'PER'}, {'entity': 'VideoMcIlroy', 'label': 'ORG'}, {'entity': 'Poppy Bayindir', 'label': 'PER'}, {'entity': 'Man Utd', 'label': 'MISC'}, {'entity': 'Onana', 'label': 'LOC'}, {'entity': 'Hibs Scotland', 'label': 'PER'}, {'entity': 'Rory McIlroy', 'label': 'PER'}, {'entity': 'Grand Slam', 'label': 'MISC'}, {'entity': 'AudioRory McIlroy', 'label': 'PER'}, {'entity':  ...

# %%
print("Processed Data:", json.dumps(processed_data, indent=2))
# Out:
# Processed Data: [
#   {
#     "title": "'Welcome to the club' - Woods leads tributes to McIlroy",
#     "entities": [
#       {
#         "entity": "McIlroy",
#         "label": "ORG"
#       },
#       {
#         "entity": "Tiger Woods",
#         "label": "PER"
#       },
#       {
#         "entity": "Rory McIlroy",
#         "label": "PER"
#       },
#       {
#         "entity": "Grand Slam",
#         "label": "MISC"
#       },
#       {
#         "entity": "Northern Ireland",
#         "label": "LOC"
#       },
#       {
#         "entity": "European",
#         "label": "MISC"
#       },
#       {
#         "entity": "Grand Slam",
#         "label": "MISC"
#       },
#       {
#         "entity": "Open Championship",
#         "label": "ORG"
#       },
#       {
#         "entity": "US Open",
#         "label": "MISC"
#       },
#       {
#         "entity": "US",
#         "label": "LOC"
#       },
#       {
#         "entity": "Woods",
#         "label": "PER"
#       },
#       {
#         "entity": "Grand Slam",
#         "label": "MISC"
#       },
#       {
#         "entity": "Americans",
#         "label": "MISC"
#       },
#       {
#         "entity": "Jack Nicklaus",
#         "label": "PER"
#       },
#       {
#         "entity": "Ben Hogan",
#         "label": "PER"
#       },
#       {
#         "entity": "Gene Sarazen",
#         "label": "PER"
#       },
#       {
#         "entity": "South Africa",
#         "label": "LOC"
#       },
#       {
#         "entity": "Gary Player",
#         "label": "PER"
#       },
#       {
#         "entity": "Woods",
#         "label": "PER"
#       },
#       {
#         "entity": "Grand Slam",
#         "label": "MISC"
#       },
#       {
#         "entity": "Augusta",
#         "label": "LOC"
#       },
#       {
#         "entity": "McIlroy",
#         "label": "PER"
#       },
#       {
#         "entity": "England",
#         "label": "LOC"
#       },
#       {
#         "entity": "Justin Rose",
#         "label": "PER"
#       },
#       {
#         "entity": "Augusta National",
#         "label": "LOC"
#       },
#       {
#         "entity": "US PGA",
#         "label": "MISC"
#       },
#       {
#         "entity": "Nicklaus,85",
#         "label": "LOC"
#       },
#       {
#         "entity": "America",
#         "label": "LOC"
#       },
#       {
#         "entity": "Rory McIlroy",
#         "label": "PER"
#       },
#       {
#         "entity": "Grand Slam",
#         "label": "MISC"
#       },
#       {
#         "entity": "BBC Radio",
#         "label": "ORG"
#       },
#       {
#         "entity": "Rory and they wanted",
#         "label": "MISC"
#       },
#       {
#         "entity": "McIlroy",
#         "label": "ORG"
#       },
#       {
#         "entity": "Grand Slam McIlroy",
#         "label": "MISC"
#       },
#       {
#         "entity": "Rose",
#         "label": "PER"
#       },
#       {
#         "entity": "Grand Slam Masters",
#         "label": "MISC"
#       },
#       {
#         "entity": "McIlroy",
#         "label": "ORG"
#       },
#       {
#         "entity": "McIlroy",
#         "label": "ORG"
#       },
#       {
#         "entity": "Masters This video",
#         "label": "MISC"
#       },
#       {
#         "entity": "Watch McIlroy",
#         "label": "PER"
#       },
#       {
#         "entity": "McIlroy",
#         "label": "PER"
#       },
#       {
#         "entity": "Rose",
#         "label": "LOC"
#       },
#       {
#         "entity": "Grand Slam",
#         "label": "MISC"
#       },
#       {
#         "entity": "Masters",
#         "label": "MISC"
#       },
#       {
#         "entity": "Grand Slam",
#         "label": "MISC"
#       },
#       {
#         "entity": "McIlroy",
#         "label": "ORG"
#       },
#       {
#         "entity": "Tiger Woods",
#         "label": "PER"
#       },
#       {
#         "entity": "Green Jacket",
#         "label": "PER"
#       },
#       {
#         "entity": "English",
#         "label": "MISC"
#       },
#       {
#         "entity": "Rose",
#         "label": "PER"
#       },
#       {
#         "entity": "McIlroy",
#         "label": "PER"
#       },
#       {
#         "entity": "Grand Slam",
#         "label": "MISC"
#       },
#       {
#         "entity": "Rose",
#         "label": "PER"
#       },
#       {
#         "entity": "McIlroy's",
#         "label": "ORG"
#       },
#       {
#         "entity": "Ryder Cup",
#         "label": "MISC"
#       },
#       {
#         "entity": "Lowry",
#         "label": "PER"
#       },
#       {
#         "entity": "BBC NI Sport",
#         "label": "ORG"
#       },
#       {
#         "entity": "Irish",
#         "label": "MISC"
#       },
#       {
#         "entity": "Lowry",
#         "label": "PER"
#       },
#       {
#         "entity": "Ireland",
#         "label": "LOC"
#       },
#       {
#         "entity": "Open",
#         "label": "MISC"
#       },
#       {
#         "entity": "Green Jacket",
#         "label": "PER"
#       },
#       {
#         "entity": "England'sTommy Fleetwoodsaid",
#         "label": "MISC"
#       },
#       {
#         "entity": "Rory McIlroy",
#         "label": "PER"
#       },
#       {
#         "entity": "Northern Ireland",
#         "label": "ORG"
#       },
#       {
#         "entity": "Open",
#         "label": "MISC"
#       },
#       {
#         "entity": "Ryder Cup",
#         "label": "MISC"
#       },
#       {
#         "entity": "Harry",
#         "label": "PER"
#       },
#       {
#         "entity": "Diamond",
#         "label": "ORG"
#       },
#       {
#         "entity": "McIlroy",
#         "label": "ORG"
#       },
#       {
#         "entity": "Bryson DeChambeau",
#         "label": "PER"
#       },
#       {
#         "entity": "American",
#         "label": "MISC"
#       },
#       {
#         "entity": "McIlroy",
#         "label": "PER"
#       },
#       {
#         "entity": "US Open",
#         "label": "MISC"
#       },
#       {
#         "entity": "McIlroy",
#         "label": "LOC"
#       },
#       {
#         "entity": "DeChambeau",
#         "label": "PER"
#       },
#       {
#         "entity": "PGA Tour",
#         "label": "MISC"
#       },
#       {
#         "entity": "LIV Golf",
#         "label": "ORG"
#       },
#       {
#         "entity": "McIlroy",
#         "label": "PER"
#       },
#       {
#         "entity": "DeChambeau",
#         "label": "PER"
#       },
#       {
#         "entity": "McIlroy",
#         "label": "PER"
#       },
#       {
#         "entity": "McIlroy",
#         "label": "ORG"
#       },
#       {
#         "entity": "Grand Slam McIlroy",
#         "label": "MISC"
#       },
#       {
#         "entity": "Harry Diamond",
#         "label": "PER"
#       },
#       {
#         "entity": "Diamond",
#         "label": "PER"
#       },
#       {
#         "entity": "McIlroy\u2019s",
#         "label": "ORG"
#       },
#       {
#         "entity": "JP Fitzgerald",
#         "label": "PER"
#       },
#       {
#         "entity": "McIlroy",
#         "label": "PER"
#       },
#       {
#         "entity": "Harry",
#         "label": "PER"
#       },
#       {
#         "entity": "Holywood Golf Club",
#         "label": "LOC"
#       },
#       {
#         "entity": "McIlroy",
#         "label": "PER"
#       },
#       {
#         "entity": "Diamond",
#         "label": "PER"
#       },
#       {
#         "entity": "Harry",
#         "label": "PER"
#       },
#       {
#         "entity": "McIlroy",
#         "label": "PER"
#       },
#       {
#         "entity": "McIlroy Podcast",
#         "label": "LOC"
#       },
#       {
#         "entity": "Rory McIlroy",
#         "label": "PER"
#       },
#       {
#         "entity": "Grand Slam",
#         "label": "MISC"
#       },
#       {
#         "entity": "Marko",
#         "label": "PER"
#       },
#       {
#         "entity": "McIlroy Modric",
#         "label": "LOC"
#       },
#       {
#         "entity": "Swansea",
#         "label": "ORG"
#       },
#       {
#         "entity": "Belinda",
#         "label": "ORG"
#       },
#       {
#         "entity": "Directed",
#         "label": "PER"
#       },
#       {
#         "entity": "Sam Mendes",
#         "label": "PER"
#       },
#       {
#         "entity": "Australian",
#         "label": "MISC"
#       },
#       {
#         "entity": "McIlroy McIlroy",
#         "label": "PER"
#       },
#       {
#         "entity": "VideoMcIlroy",
#         "label": "ORG"
#       },
#       {
#         "entity": "Corner",
#         "label": "PER"
#       },
#       {
#         "entity": "Delap",
#         "label": "ORG"
#       },
#       {
#         "entity": "McIlroy",
#         "label": "ORG"
#       },
#       {
#         "entity": "Masters Can Swiatek",
#         "label": "ORG"
#       },
#       {
#         "entity": "Alcaraz",
#         "label": "ORG"
#       },
#       {
#         "entity": "McIlroy",
#         "label": "PER"
#       },
#       {
#         "entity": "Poppy",
#         "label": "PER"
#       },
#       {
#         "entity": "VideoMcIlroy",
#         "label": "ORG"
#       },
#       {
#         "entity": "Poppy Bayindir",
#         "label": "PER"
#       },
#       {
#         "entity": "Man Utd",
#         "label": "MISC"
#       },
#       {
#         "entity": "Onana",
#         "label": "LOC"
#       },
#       {
#         "entity": "Hibs Scotland",
#         "label": "PER"
#       },
#       {
#         "entity": "Rory McIlroy",
#         "label": "PER"
#       },
#       {
#         "entity": "Grand Slam",
#         "label": "MISC"
#       },
#       {
#         "entity": "AudioRory McIlroy",
#         "label": "PER"
#       },
#       {
#         "entity": "Grand Slam",
#         "label": "MISC"
#       },
#       {
#         "entity": "Newcastle",
#         "label": "ORG"
#       },
#       {
#         "entity": "Howe What's",
#         "label": "MISC"
#       },
#       {
#         "entity": "Man City",
#         "label": "LOC"
#       },
#       {
#         "entity": "Kevin",
#         "label": "PER"
#       },
#       {
#         "entity": "De Bruyne",
#         "label": "PER"
#       },
#       {
#         "entity": "Dominant Pimblett",
#         "label": "PER"
#       },
#       {
#         "entity": "Chandler",
#         "label": "PER"
#       },
#       {
#         "entity": "UFC",
#         "label": "ORG"
#       },
#       {
#         "entity": "England",
#         "label": "LOC"
#       },
#       {
#         "entity": "Leinster",
#         "label": "ORG"
#       },
#       {
#         "entity": "Europe",
#         "label": "LOC"
#       },
#       {
#         "entity": "Salah",
#         "label": "PER"
#       },
#       {
#         "entity": "Saudi",
#         "label": "MISC"
#       },
#       {
#         "entity": "Liverpool",
#         "label": "ORG"
#       },
#       {
#         "entity": "Explainer",
#         "label": "PER"
#       },
#       {
#         "entity": "Semi",
#         "label": "PER"
#       },
#       {
#         "entity": "Premier League The",
#         "label": "MISC"
#       },
#       {
#         "entity": "Wrexham Deadpool",
#         "label": "MISC"
#       },
#       {
#         "entity": "Mullin",
#         "label": "LOC"
#       },
#       {
#         "entity": "Lamine Yamal",
#         "label": "MISC"
#       },
#       {
#         "entity": "Lamine Yamal Copyright",
#         "label": "ORG"
#       }
#     ],
#     "relations": [
#       {
#         "subject": "video",
#         "predicate": "play",
#         "object": "triumph"
#       },
#       {
#         "subject": "old",
#         "predicate": "become",
#         "object": "man"
#       },
#       {
#         "subject": "which",
#         "predicate": "secure",
#         "object": "victory"
#       },
#       {
#         "subject": "he",
#         "predicate": "win",
#         "object": "major"
#       },
#       {
#         "subject": "It",
#         "predicate": "take",
#         "object": "world"
#       },
#       {
#         "subject": "Player",
#         "predicate": "tell",
#         "object": "Live"
#       },
#       {
#         "subject": "He",
#         "predicate": "have",
#         "object": "swing"
#       },
#       {
#         "subject": "he",
#         "predicate": "deserve",
#         "object": "everything"
#       },
#       {
#         "subject": "I",
#         "predicate": "see",
#         "object": "enthusiasm"
#       },
#       {
#         "subject": "They",
#         "predicate": "follow",
#         "object": "Rory"
#       },
#       {
#         "subject": "who",
#         "predicate": "do",
#         "object": "lot"
#       },
#       {
#         "subject": "McIlroy",
#         "predicate": "win",
#         "object": "Masters"
#       },
#       {
#         "subject": "McIlroy",
#         "predicate": "beat",
#         "object": "Rose"
#       },
#       {
#         "subject": "that",
#         "predicate": "win",
#         "object": "McIlroy"
#       },
#       {
#         "subject": "McIlroy",
#         "predicate": "claim",
#         "object": "jacket"
#       },
#       {
#         "subject": "who",
#         "predicate": "shoot",
#         "object": "one"
#       },
#       {
#         "subject": "which",
#         "predicate": "take",
#         "object": "place"
#       },
#       {
#         "subject": "McIlroy",
#         "predicate": "ask",
#         "object": "media"
#       },
#       {
#         "subject": "that",
#         "predicate": "inspire",
#         "object": "many"
#       },
#       {
#         "subject": "he",
#         "predicate": "do",
#         "object": "what"
#       },
#       {
#         "subject": "He",
#         "predicate": "have",
#         "object": "words"
#       },
#       {
#         "subject": "he",
#         "predicate": "tell",
#         "object": "champion"
#       },
#       {
#         "subject": "who",
#         "predicate": "achieve",
#         "object": "Slam"
#       },
#       {
#         "subject": "Lowry",
#         "predicate": "tell",
#         "object": "Sport"
#       },
#       {
#         "subject": "I",
#         "predicate": "have",
#         "object": "day"
#       },
#       {
#         "subject": "he",
#         "predicate": "retire",
#         "object": "man"
#       },
#       {
#         "subject": "he",
#         "predicate": "win",
#         "object": "Jacket"
#       },
#       {
#         "subject": "nobody",
#         "predicate": "write",
#         "object": "script"
#       },
#       {
#         "subject": "he",
#         "predicate": "achieve",
#         "object": "something"
#       },
#       {
#         "subject": "I",
#         "predicate": "know",
#         "object": "Rory"
#       },
#       {
#         "subject": "I",
#         "predicate": "watch",
#         "object": "boys"
#       },
#       {
#         "subject": "Rory",
#         "predicate": "join",
#         "object": "echelon"
#       },
#       {
#         "subject": "American",
#         "predicate": "start",
#         "object": "day"
#       },
#       {
#         "subject": "who",
#         "predicate": "beat",
#         "object": "McIlroy"
#       },
#       {
#         "subject": "he",
#         "predicate": "reply",
#         "object": "idea"
#       },
#       {
#         "subject": "he",
#         "predicate": "put",
#         "object": "approach"
#       },
#       {
#         "subject": "Masters",
#         "predicate": "play",
#         "object": "off"
#       },
#       {
#         "subject": "who",
#         "predicate": "become",
#         "object": "caddie"
#       },
#       {
#         "subject": "I",
#         "predicate": "know",
#         "object": "Harry"
#       },
#       {
#         "subject": "I",
#         "predicate": "meet",
#         "object": "him"
#       },
#       {
#         "subject": "We",
#         "predicate": "have",
#         "object": "times"
#       },
#       {
#         "subject": "we",
#         "predicate": "have",
#         "object": "that"
#       },
#       {
#         "subject": "that",
#         "predicate": "know",
#         "object": "anything"
#       },
#       {
#         "subject": "McIlroy",
#         "predicate": "point",
#         "object": "role"
#       },
#       {
#         "subject": "we",
#         "predicate": "take",
#         "object": "this"
#       },
#       {
#         "subject": "I",
#         "predicate": "hit",
#         "object": "drive"
#       },
#       {
#         "subject": "McIlroy",
#         "predicate": "complete",
#         "object": "Slam"
#       },
#       {
#         "subject": "Woods",
#         "predicate": "lead",
#         "object": "tributes"
#       },
#       {
#         "subject": "face",
#         "predicate": "change",
#         "object": "everything"
#       },
#       {
#         "subject": "that",
#         "predicate": "win",
#         "object": "McIlroy"
#       },
#       {
#         "subject": "McIlroy",
#         "predicate": "complete",
#         "object": "Slam"
#       },
#       {
#         "subject": "McIlroy",
#         "predicate": "complete",
#         "object": "Slam"
#       },
#       {
#         "subject": "Kevin",
#         "predicate": "have",
#         "object": "what"
#       },
#       {
#         "subject": "Pimblett",
#         "predicate": "stop",
#         "object": "Chandler"
#       },
#       {
#         "subject": "who",
#         "predicate": "stop",
#         "object": "Leinster"
#       },
#       {
#         "subject": "Salah",
#         "predicate": "turn",
#         "object": "rise"
#       }
#     ]
#   },
#   {
#     "title": "Modric to become Swansea minority owner",
#     "entities": [
#       {
#         "entity": "Luka Modric",
#         "label": "PER"
#       },
#       {
#         "entity": "Ballon",
#         "label": "ORG"
#       },
#       {
#         "entity": "Real Madrid",
#         "label": "ORG"
#       },
#       {
#         "entity": "Croatia",
#         "label": "LOC"
#       },
#       {
#         "entity": "Luka Modric",
#         "label": "PER"
#       },
#       {
#         "entity": "Swansea City",
#         "label": "LOC"
#       },
#       {
#         "entity": "Andy Coleman",
#         "label": "PER"
#       },
#       {
#         "entity": "Brett Cravatt",
#         "label": "PER"
#       },
#       {
#         "entity": "Nigel Morris",
#         "label": "PER"
#       },
#       {
#         "entity": "Jason Cohen",
#         "label": "PER"
#       },
#       {
#         "entity": "Jason Levien",
#         "label": "PER"
#       },
#       {
#         "entity": "Steve Kaplanlast",
#         "label": "PER"
#       },
#       {
#         "entity": "Modric",
#         "label": "PER"
#       },
#       {
#         "entity": "Real Madrid",
#         "label": "ORG"
#       },
#       {
#         "entity": "Modric",
#         "label": "PER"
#       },
#       {
#         "entity": "Real Madrid",
#         "label": "ORG"
#       },
#       {
#         "entity": "Swansea City",
#         "label": "ORG"
#       },
#       {
#         "entity": "Luka Modric",
#         "label": "PER"
#       },
#       {
#         "entity": "Tottenham Hotspur",
#         "label": "PER"
#       },
#       {
#         "entity": "Joe Allen",
#         "label": "PER"
#       },
#       {
#         "entity": "Swansea City",
#         "label": "PER"
#       },
#       {
#         "entity": "Allen",
#         "label": "PER"
#       },
#       {
#         "entity": "Swansea",
#         "label": "LOC"
#       },
#       {
#         "entity": "Modric",
#         "label": "PER"
#       },
#       {
#         "entity": "Real Madrid Modric",
#         "label": "ORG"
#       },
#       {
#         "entity": "Swansea",
#         "label": "PER"
#       },
#       {
#         "entity": "Swansea",
#         "label": "PER"
#       },
#       {
#         "entity": "EFL Championship",
#         "label": "ORG"
#       },
#       {
#         "entity": "EFL",
#         "label": "ORG"
#       },
#       {
#         "entity": "Premier League",
#         "label": "MISC"
#       },
#       {
#         "entity": "Comments",
#         "label": "ORG"
#       },
#       {
#         "entity": "JavaScript",
#         "label": "PER"
#       },
#       {
#         "entity": "Marko",
#         "label": "PER"
#       },
#       {
#         "entity": "McIlroy Modric",
#         "label": "LOC"
#       },
#       {
#         "entity": "Swansea",
#         "label": "ORG"
#       },
#       {
#         "entity": "Belinda",
#         "label": "ORG"
#       },
#       {
#         "entity": "Directed",
#         "label": "PER"
#       },
#       {
#         "entity": "Sam Mendes",
#         "label": "PER"
#       },
#       {
#         "entity": "Australian",
#         "label": "MISC"
#       },
#       {
#         "entity": "McIlroy McIlroy",
#         "label": "PER"
#       },
#       {
#         "entity": "VideoMcIlroy",
#         "label": "ORG"
#       },
#       {
#         "entity": "Corner",
#         "label": "PER"
#       },
#       {
#         "entity": "Delap",
#         "label": "ORG"
#       },
#       {
#         "entity": "McIlroy",
#         "label": "ORG"
#       },
#       {
#         "entity": "Masters Can Swiatek",
#         "label": "ORG"
#       },
#       {
#         "entity": "Alcaraz",
#         "label": "ORG"
#       },
#       {
#         "entity": "McIlroy",
#         "label": "PER"
#       },
#       {
#         "entity": "Poppy",
#         "label": "PER"
#       },
#       {
#         "entity": "VideoMcIlroy",
#         "label": "ORG"
#       },
#       {
#         "entity": "Poppy Bayindir",
#         "label": "PER"
#       },
#       {
#         "entity": "Man Utd",
#         "label": "MISC"
#       },
#       {
#         "entity": "Onana",
#         "label": "LOC"
#       },
#       {
#         "entity": "Hibs Scotland",
#         "label": "PER"
#       },
#       {
#         "entity": "Rory McIlroy",
#         "label": "PER"
#       },
#       {
#         "entity": "Grand Slam",
#         "label": "MISC"
#       },
#       {
#         "entity": "AudioRory McIlroy",
#         "label": "PER"
#       },
#       {
#         "entity": "Grand Slam",
#         "label": "MISC"
#       },
#       {
#         "entity": "Newcastle",
#         "label": "ORG"
#       },
#       {
#         "entity": "Howe What's",
#         "label": "MISC"
#       },
#       {
#         "entity": "Man City",
#         "label": "LOC"
#       },
#       {
#         "entity": "Kevin",
#         "label": "PER"
#       },
#       {
#         "entity": "De Bruyne",
#         "label": "PER"
#       },
#       {
#         "entity": "Dominant Pimblett",
#         "label": "PER"
#       },
#       {
#         "entity": "Chandler",
#         "label": "PER"
#       },
#       {
#         "entity": "UFC",
#         "label": "ORG"
#       },
#       {
#         "entity": "England",
#         "label": "LOC"
#       },
#       {
#         "entity": "Leinster",
#         "label": "ORG"
#       },
#       {
#         "entity": "Europe",
#         "label": "LOC"
#       },
#       {
#         "entity": "Salah",
#         "label": "PER"
#       },
#       {
#         "entity": "Saudi",
#         "label": "MISC"
#       },
#       {
#         "entity": "Liverpool",
#         "label": "ORG"
#       },
#       {
#         "entity": "Explainer",
#         "label": "PER"
#       },
#       {
#         "entity": "Semi",
#         "label": "PER"
#       },
#       {
#         "entity": "Premier League The",
#         "label": "MISC"
#       },
#       {
#         "entity": "Wrexham Deadpool",
#         "label": "MISC"
#       },
#       {
#         "entity": "Mullin",
#         "label": "LOC"
#       },
#       {
#         "entity": "Lamine Yamal",
#         "label": "MISC"
#       },
#       {
#         "entity": "Lamine Yamal Copyright",
#         "label": "ORG"
#       }
#     ],
#     "relations": [
#       {
#         "subject": "Modric",
#         "predicate": "win",
#         "object": "d'Or"
#       },
#       {
#         "subject": "That",
#         "predicate": "cohortpurchase",
#         "object": "shares"
#       },
#       {
#         "subject": "which",
#         "predicate": "post",
#         "object": "loss"
#       },
#       {
#         "subject": "Swansea",
#         "predicate": "post",
#         "object": "turnover"
#       },
#       {
#         "subject": "Woods",
#         "predicate": "lead",
#         "object": "tributes"
#       },
#       {
#         "subject": "face",
#         "predicate": "change",
#         "object": "everything"
#       },
#       {
#         "subject": "that",
#         "predicate": "win",
#         "object": "McIlroy"
#       },
#       {
#         "subject": "McIlroy",
#         "predicate": "complete",
#         "object": "Slam"
#       },
#       {
#         "subject": "McIlroy",
#         "predicate": "complete",
#         "object": "Slam"
#       },
#       {
#         "subject": "Kevin",
#         "predicate": "have",
#         "object": "what"
#       },
#       {
#         "subject": "Pimblett",
#         "predicate": "stop",
#         "object": "Chandler"
#       },
#       {
#         "subject": "who",
#         "predicate": "stop",
#         "object": "Leinster"
#       },
#       {
#         "subject": "Salah",
#         "predicate": "turn",
#         "object": "rise"
#       }
#     ]
#   },
#   {
#     "title": "Corner chicken & Rory Delap 2.0 - what's the future of football?",
#     "entities": [
#       {
#         "entity": "Corner",
#         "label": "PER"
#       },
#       {
#         "entity": "Delap",
#         "label": "ORG"
#       },
#       {
#         "entity": "English",
#         "label": "MISC"
#       },
#       {
#         "entity": "mid-2010s",
#         "label": "MISC"
#       },
#       {
#         "entity": "Antonio Conte",
#         "label": "PER"
#       },
#       {
#         "entity": "Pep Guardiola",
#         "label": "PER"
#       },
#       {
#         "entity": "Jurgen Klopp",
#         "label": "PER"
#       },
#       {
#         "entity": "Europe",
#         "label": "LOC"
#       },
#       {
#         "entity": "Guardiola",
#         "label": "PER"
#       },
#       {
#         "entity": "Manchester City",
#         "label": "LOC"
#       },
#       {
#         "entity": "Tuchel",
#         "label": "PER"
#       },
#       {
#         "entity": "England",
#         "label": "LOC"
#       },
#       {
#         "entity": "Why Guardiola",
#         "label": "PER"
#       },
#       {
#         "entity": "Bournemouth",
#         "label": "ORG"
#       },
#       {
#         "entity": "Let",
#         "label": "ORG"
#       },
#       {
#         "entity": "Roberto de Zerbi",
#         "label": "PER"
#       },
#       {
#         "entity": "Brighton",
#         "label": "ORG"
#       },
#       {
#         "entity": "De Zerbi",
#         "label": "PER"
#       },
#       {
#         "entity": "Trojan",
#         "label": "LOC"
#       },
#       {
#         "entity": "Or",
#         "label": "LOC"
#       },
#       {
#         "entity": "Time",
#         "label": "PER"
#       },
#       {
#         "entity": "Premier League",
#         "label": "MISC"
#       },
#       {
#         "entity": "Except",
#         "label": "PER"
#       },
#       {
#         "entity": "Delap",
#         "label": "PER"
#       },
#       {
#         "entity": "Stoke City",
#         "label": "ORG"
#       },
#       {
#         "entity": "Hull City",
#         "label": "PER"
#       },
#       {
#         "entity": "Boaz Myhill",
#         "label": "PER"
#       },
#       {
#         "entity": "Delap",
#         "label": "PER"
#       },
#       {
#         "entity": "Delap",
#         "label": "PER"
#       },
#       {
#         "entity": "Delap",
#         "label": "PER"
#       },
#       {
#         "entity": "Mikel Arteta",
#         "label": "PER"
#       },
#       {
#         "entity": "Tony Pulis",
#         "label": "PER"
#       },
#       {
#         "entity": "Stoke",
#         "label": "PER"
#       },
#       {
#         "entity": "Delap",
#         "label": "PER"
#       },
#       {
#         "entity": "Rick Barry",
#         "label": "PER"
#       },
#       {
#         "entity": "Barry",
#         "label": "PER"
#       },
#       {
#         "entity": "NBA",
#         "label": "ORG"
#       },
#       {
#         "entity": "Shaquille O'Neal",
#         "label": "PER"
#       },
#       {
#         "entity": "Barry",
#         "label": "PER"
#       },
#       {
#         "entity": "Delap",
#         "label": "ORG"
#       },
#       {
#         "entity": "Chris Wilder",
#         "label": "PER"
#       },
#       {
#         "entity": "Sheffield United",
#         "label": "LOC"
#       },
#       {
#         "entity": "England",
#         "label": "LOC"
#       },
#       {
#         "entity": "Thomas Tuchel",
#         "label": "PER"
#       },
#       {
#         "entity": "Ange Postecoglou",
#         "label": "LOC"
#       },
#       {
#         "entity": "Franco Baresi",
#         "label": "PER"
#       },
#       {
#         "entity": "England Rio Ferdinand",
#         "label": "LOC"
#       },
#       {
#         "entity": "Destiny Udogie",
#         "label": "ORG"
#       },
#       {
#         "entity": "Tottenham Hotspur",
#         "label": "LOC"
#       },
#       {
#         "entity": "Harry Kane",
#         "label": "PER"
#       },
#       {
#         "entity": "OK",
#         "label": "ORG"
#       },
#       {
#         "entity": "Liverpool",
#         "label": "ORG"
#       },
#       {
#         "entity": "League One",
#         "label": "MISC"
#       },
#       {
#         "entity": "EFL Cup",
#         "label": "MISC"
#       },
#       {
#         "entity": "Goalkeeper Alisson",
#         "label": "PER"
#       },
#       {
#         "entity": "Arne Slot",
#         "label": "PER"
#       },
#       {
#         "entity": "Alisson",
#         "label": "PER"
#       },
#       {
#         "entity": "Arnold",
#         "label": "LOC"
#       },
#       {
#         "entity": "Trent",
#         "label": "PER"
#       },
#       {
#         "entity": "Alexander",
#         "label": "LOC"
#       },
#       {
#         "entity": "Arnold",
#         "label": "LOC"
#       },
#       {
#         "entity": "Liverpool",
#         "label": "ORG"
#       },
#       {
#         "entity": "Alexander",
#         "label": "LOC"
#       },
#       {
#         "entity": "Arnold",
#         "label": "LOC"
#       },
#       {
#         "entity": "Football Daily",
#         "label": "PER"
#       },
#       {
#         "entity": "Get",
#         "label": "ORG"
#       },
#       {
#         "entity": "Comments",
#         "label": "ORG"
#       },
#       {
#         "entity": "Comments",
#         "label": "ORG"
#       },
#       {
#         "entity": "JavaScript",
#         "label": "PER"
#       }
#     ],
#     "relations": [
#       {
#         "subject": "decade",
#         "predicate": "have",
#         "object": "theme"
#       },
#       {
#         "subject": "Conte",
#         "predicate": "attract",
#         "object": "coaches"
#       },
#       {
#         "subject": "Guardiola",
#         "predicate": "tread",
#         "object": "water"
#       },
#       {
#         "subject": "Zerbi",
#         "predicate": "stretch",
#         "object": "pitch"
#       },
#       {
#         "subject": "He",
#         "predicate": "keep",
#         "object": "players"
#       },
#       {
#         "subject": "Brighton",
#         "predicate": "kick",
#         "object": "it"
#       },
#       {
#         "subject": "This",
#         "predicate": "create",
#         "object": "scenarios"
#       },
#       {
#         "subject": "you",
#         "predicate": "decluttere",
#         "object": "area"
#       },
#       {
#         "subject": "lot",
#         "predicate": "reject",
#         "object": "idea"
#       },
#       {
#         "subject": "nobody",
#         "predicate": "change",
#         "object": "formation"
#       },
#       {
#         "subject": "nobody",
#         "predicate": "do",
#         "object": "it"
#       },
#       {
#         "subject": "they",
#         "predicate": "feel",
#         "object": "other"
#       },
#       {
#         "subject": "triangle",
#         "predicate": "become",
#         "object": "four"
#       },
#       {
#         "subject": "team",
#         "predicate": "have",
#         "object": "advantage"
#       },
#       {
#         "subject": "who",
#         "predicate": "plan",
#         "object": "switches"
#       },
#       {
#         "subject": "it",
#         "predicate": "have",
#         "object": "impact"
#       },
#       {
#         "subject": "it",
#         "predicate": "require",
#         "object": "way"
#       },
#       {
#         "subject": "We",
#         "predicate": "watch",
#         "object": "manager"
#       },
#       {
#         "subject": "we",
#         "predicate": "find",
#         "object": "what"
#       },
#       {
#         "subject": "that",
#         "predicate": "prevent",
#         "object": "it"
#       },
#       {
#         "subject": "Arteta",
#         "predicate": "bring",
#         "object": "Delap"
#       },
#       {
#         "subject": "he",
#         "predicate": "take",
#         "object": "comparisons"
#       },
#       {
#         "subject": "nobody",
#         "predicate": "copy",
#         "object": "technique"
#       },
#       {
#         "subject": "O'Neal",
#         "predicate": "sum",
#         "object": "problem"
#       },
#       {
#         "subject": "someone",
#         "predicate": "break",
#         "object": "barrier"
#       },
#       {
#         "subject": "who",
#         "predicate": "deploy",
#         "object": "three"
#       },
#       {
#         "subject": "Tuchel",
#         "predicate": "instruct",
#         "object": "backs"
#       },
#       {
#         "subject": "we",
#         "predicate": "give",
#         "object": "responsibilities"
#       },
#       {
#         "subject": "we",
#         "predicate": "take",
#         "object": "one"
#       },
#       {
#         "subject": "Kane",
#         "predicate": "don",
#         "object": "gloves"
#       },
#       {
#         "subject": "he",
#         "predicate": "have",
#         "object": "range"
#       },
#       {
#         "subject": "you",
#         "predicate": "want",
#         "object": "him"
#       },
#       {
#         "subject": "Slot",
#         "predicate": "withdraw",
#         "object": "Alisson"
#       },
#       {
#         "subject": "Arnold",
#         "predicate": "encourage",
#         "object": "shot"
#       },
#       {
#         "subject": "goalkeepers",
#         "predicate": "keep",
#         "object": "that"
#       },
#       {
#         "subject": "innovation",
#         "predicate": "require",
#         "object": "thinking"
#       },
#       {
#         "subject": "Arnold",
#         "predicate": "do",
#         "object": "what"
#       }
#     ]
#   },
#   {
#     "title": "Can Swiatek emulate Alcaraz to start clay season?",
#     "entities": [
#       {
#         "entity": "Second Serve",
#         "label": "PER"
#       },
#       {
#         "entity": "BBC",
#         "label": "ORG"
#       },
#       {
#         "entity": "Amy Lofthouse",
#         "label": "PER"
#       },
#       {
#         "entity": "Iga Swiatek",
#         "label": "ORG"
#       },
#       {
#         "entity": "Stuttgart Open",
#         "label": "MISC"
#       },
#       {
#         "entity": "Poland",
#         "label": "LOC"
#       },
#       {
#         "entity": "WTA",
#         "label": "ORG"
#       },
#       {
#         "entity": "Madrid",
#         "label": "LOC"
#       },
#       {
#         "entity": "Italy",
#         "label": "LOC"
#       },
#       {
#         "entity": "French Open",
#         "label": "MISC"
#       },
#       {
#         "entity": "Jessica Pegula",
#         "label": "PER"
#       },
#       {
#         "entity": "Clay",
#         "label": "PER"
#       },
#       {
#         "entity": "Australian Open",
#         "label": "MISC"
#       },
#       {
#         "entity": "Miami Openby Filipina",
#         "label": "ORG"
#       },
#       {
#         "entity": "Alexandra Eala",
#         "label": "PER"
#       },
#       {
#         "entity": "Swiatek",
#         "label": "PER"
#       },
#       {
#         "entity": "Miami",
#         "label": "LOC"
#       },
#       {
#         "entity": "Carlos Alcaraz",
#         "label": "PER"
#       },
#       {
#         "entity": "Alcaraz",
#         "label": "ORG"
#       },
#       {
#         "entity": "French Open",
#         "label": "MISC"
#       },
#       {
#         "entity": "Miami",
#         "label": "LOC"
#       },
#       {
#         "entity": "Swiatek",
#         "label": "PER"
#       },
#       {
#         "entity": "Monte Carlo",
#         "label": "LOC"
#       },
#       {
#         "entity": "Arthur Fils",
#         "label": "LOC"
#       },
#       {
#         "entity": "Spaniard",
#         "label": "MISC"
#       },
#       {
#         "entity": "Lorenzo Musetti",
#         "label": "PER"
#       },
#       {
#         "entity": "Alcaraz",
#         "label": "ORG"
#       },
#       {
#         "entity": "Swiatek",
#         "label": "PER"
#       },
#       {
#         "entity": "Stuttgart",
#         "label": "LOC"
#       },
#       {
#         "entity": "Katie Boulter",
#         "label": "PER"
#       },
#       {
#         "entity": "Jodie Burrage",
#         "label": "PER"
#       },
#       {
#         "entity": "Great Britain",
#         "label": "PER"
#       },
#       {
#         "entity": "Billie Jean",
#         "label": "PER"
#       },
#       {
#         "entity": "Emma Raducanuis",
#         "label": "PER"
#       },
#       {
#         "entity": "Mark Petchy",
#         "label": "PER"
#       },
#       {
#         "entity": "Billie Jean Kingreceived",
#         "label": "PER"
#       },
#       {
#         "entity": "Hollywood Walk of Fame",
#         "label": "ORG"
#       },
#       {
#         "entity": "WTA",
#         "label": "ORG"
#       },
#       {
#         "entity": "Billie Jean King Cup",
#         "label": "MISC"
#       },
#       {
#         "entity": "Lorenzo Musetti'sMonte Carlo",
#         "label": "PER"
#       },
#       {
#         "entity": "Musetti",
#         "label": "PER"
#       },
#       {
#         "entity": "Stefanos Tsitsipas",
#         "label": "PER"
#       },
#       {
#         "entity": "Alex de Minaur",
#         "label": "PER"
#       },
#       {
#         "entity": "Alcaraz",
#         "label": "ORG"
#       },
#       {
#         "entity": "Stuttgart Open",
#         "label": "MISC"
#       },
#       {
#         "entity": "Porsche",
#         "label": "ORG"
#       },
#       {
#         "entity": "WTA Tour",
#         "label": "MISC"
#       },
#       {
#         "entity": "includingAryna Sabalenka",
#         "label": "ORG"
#       },
#       {
#         "entity": "Jessica PegulaandMirra",
#         "label": "PER"
#       },
#       {
#         "entity": "US Open",
#         "label": "MISC"
#       },
#       {
#         "entity": "Andreescu",
#         "label": "LOC"
#       },
#       {
#         "entity": "Open de Rouen",
#         "label": "MISC"
#       },
#       {
#         "entity": "France",
#         "label": "LOC"
#       },
#       {
#         "entity": "Alcaraz",
#         "label": "ORG"
#       },
#       {
#         "entity": "Barcelona Open",
#         "label": "MISC"
#       },
#       {
#         "entity": "RuudandAndrey Rublev",
#         "label": "PER"
#       },
#       {
#         "entity": "whileAlexander Zverevis",
#         "label": "PER"
#       },
#       {
#         "entity": "Munich Open",
#         "label": "MISC"
#       },
#       {
#         "entity": "British",
#         "label": "MISC"
#       },
#       {
#         "entity": "Lloyd Glasspoolbegan",
#         "label": "PER"
#       },
#       {
#         "entity": "Monte Carlo Masters",
#         "label": "ORG"
#       },
#       {
#         "entity": "Romain Arneodo",
#         "label": "PER"
#       },
#       {
#         "entity": "France",
#         "label": "LOC"
#       },
#       {
#         "entity": "Manuel Guinard",
#         "label": "PER"
#       },
#       {
#         "entity": "Finnish",
#         "label": "MISC"
#       },
#       {
#         "entity": "Harri Heliovaara",
#         "label": "PER"
#       },
#       {
#         "entity": "Monaco",
#         "label": "LOC"
#       },
#       {
#         "entity": "whileGiles Husseytriumphed",
#         "label": "PER"
#       },
#       {
#         "entity": "ITF M15",
#         "label": "ORG"
#       },
#       {
#         "entity": "Monastir",
#         "label": "PER"
#       },
#       {
#         "entity": "Sonay Kartal",
#         "label": "PER"
#       },
#       {
#         "entity": "BJK Cup",
#         "label": "MISC"
#       },
#       {
#         "entity": "Open de Rouen",
#         "label": "MISC"
#       },
#       {
#         "entity": "Dartalso",
#         "label": "PER"
#       },
#       {
#         "entity": "Cameron Norriecame",
#         "label": "PER"
#       },
#       {
#         "entity": "Barcelona",
#         "label": "LOC"
#       },
#       {
#         "entity": "Jacob Fearnleylost",
#         "label": "PER"
#       },
#       {
#         "entity": "Harrisin Munich",
#         "label": "PER"
#       },
#       {
#         "entity": "Lucy ShukerandBen Bartramare",
#         "label": "PER"
#       },
#       {
#         "entity": "Japan Open",
#         "label": "MISC"
#       },
#       {
#         "entity": "BBC Sport",
#         "label": "ORG"
#       },
#       {
#         "entity": "Second Serve",
#         "label": "PER"
#       },
#       {
#         "entity": "ATP",
#         "label": "ORG"
#       },
#       {
#         "entity": "WTA",
#         "label": "ORG"
#       },
#       {
#         "entity": "British",
#         "label": "MISC"
#       },
#       {
#         "entity": "BBC Sport",
#         "label": "ORG"
#       },
#       {
#         "entity": "Comments",
#         "label": "ORG"
#       },
#       {
#         "entity": "JavaScript",
#         "label": "PER"
#       },
#       {
#         "entity": "Marko",
#         "label": "PER"
#       },
#       {
#         "entity": "McIlroy Modric",
#         "label": "LOC"
#       },
#       {
#         "entity": "Swansea",
#         "label": "ORG"
#       },
#       {
#         "entity": "Belinda",
#         "label": "ORG"
#       },
#       {
#         "entity": "Directed",
#         "label": "PER"
#       },
#       {
#         "entity": "Sam Mendes",
#         "label": "PER"
#       },
#       {
#         "entity": "Australian",
#         "label": "MISC"
#       },
#       {
#         "entity": "McIlroy McIlroy",
#         "label": "PER"
#       },
#       {
#         "entity": "VideoMcIlroy",
#         "label": "ORG"
#       },
#       {
#         "entity": "Corner",
#         "label": "PER"
#       },
#       {
#         "entity": "Delap",
#         "label": "ORG"
#       },
#       {
#         "entity": "McIlroy",
#         "label": "ORG"
#       },
#       {
#         "entity": "Masters Can Swiatek",
#         "label": "ORG"
#       },
#       {
#         "entity": "Alcaraz",
#         "label": "ORG"
#       },
#       {
#         "entity": "McIlroy",
#         "label": "PER"
#       },
#       {
#         "entity": "Poppy",
#         "label": "PER"
#       },
#       {
#         "entity": "VideoMcIlroy",
#         "label": "ORG"
#       },
#       {
#         "entity": "Poppy Bayindir",
#         "label": "PER"
#       },
#       {
#         "entity": "Man Utd",
#         "label": "MISC"
#       },
#       {
#         "entity": "Onana",
#         "label": "LOC"
#       },
#       {
#         "entity": "Hibs Scotland",
#         "label": "PER"
#       },
#       {
#         "entity": "Rory McIlroy",
#         "label": "PER"
#       },
#       {
#         "entity": "Grand Slam",
#         "label": "MISC"
#       },
#       {
#         "entity": "AudioRory McIlroy",
#         "label": "PER"
#       },
#       {
#         "entity": "Grand Slam",
#         "label": "MISC"
#       },
#       {
#         "entity": "Newcastle",
#         "label": "ORG"
#       },
#       {
#         "entity": "Howe What's",
#         "label": "MISC"
#       },
#       {
#         "entity": "Man City",
#         "label": "LOC"
#       },
#       {
#         "entity": "Kevin",
#         "label": "PER"
#       },
#       {
#         "entity": "De Bruyne",
#         "label": "PER"
#       },
#       {
#         "entity": "Dominant Pimblett",
#         "label": "PER"
#       },
#       {
#         "entity": "Chandler",
#         "label": "PER"
#       },
#       {
#         "entity": "UFC",
#         "label": "ORG"
#       },
#       {
#         "entity": "England",
#         "label": "LOC"
#       },
#       {
#         "entity": "Leinster",
#         "label": "ORG"
#       },
#       {
#         "entity": "Europe",
#         "label": "LOC"
#       },
#       {
#         "entity": "Salah",
#         "label": "PER"
#       },
#       {
#         "entity": "Saudi",
#         "label": "MISC"
#       },
#       {
#         "entity": "Liverpool",
#         "label": "ORG"
#       },
#       {
#         "entity": "Explainer",
#         "label": "PER"
#       },
#       {
#         "entity": "Semi",
#         "label": "PER"
#       },
#       {
#         "entity": "Premier League The",
#         "label": "MISC"
#       },
#       {
#         "entity": "Wrexham Deadpool",
#         "label": "MISC"
#       },
#       {
#         "entity": "Mullin",
#         "label": "LOC"
#       },
#       {
#         "entity": "Lamine Yamal",
#         "label": "MISC"
#       },
#       {
#         "entity": "Lamine Yamal Copyright",
#         "label": "ORG"
#       }
#     ],
#     "relations": [
#       {
#         "subject": "number",
#         "predicate": "defend",
#         "object": "points"
#       },
#       {
#         "subject": "she",
#         "predicate": "reach",
#         "object": "semi"
#       },
#       {
#         "subject": "Swiatek",
#         "predicate": "win",
#         "object": "titles"
#       },
#       {
#         "subject": "she",
#         "predicate": "defend",
#         "object": "%"
#       },
#       {
#         "subject": "Pegula",
#         "predicate": "defend",
#         "object": "none"
#       },
#       {
#         "subject": "return",
#         "predicate": "provide",
#         "object": "reset"
#       },
#       {
#         "subject": "He",
#         "predicate": "have",
#         "object": "start"
#       },
#       {
#         "subject": "He",
#         "predicate": "have",
#         "object": "loss"
#       },
#       {
#         "subject": "champion",
#         "predicate": "have",
#         "object": "it"
#       },
#       {
#         "subject": "Raducanuis",
#         "predicate": "turn",
#         "object": "Petchy"
#       },
#       {
#         "subject": "which",
#         "predicate": "offer",
#         "object": "points"
#       },
#       {
#         "subject": "run",
#         "predicate": "leave",
#         "object": "him"
#       },
#       {
#         "subject": "Owner",
#         "predicate": "beat",
#         "object": "Tsitsipas"
#       },
#       {
#         "subject": "Musetti",
#         "predicate": "beat",
#         "object": "Tsitsipas"
#       },
#       {
#         "subject": "injury",
#         "predicate": "hold",
#         "object": "season"
#       },
#       {
#         "subject": "that",
#         "predicate": "hamper",
#         "object": "him"
#       },
#       {
#         "subject": "Alcaraz",
#         "predicate": "head",
#         "object": "field"
#       },
#       {
#         "subject": "British",
#         "predicate": "double",
#         "object": "Cash"
#       },
#       {
#         "subject": "duo",
#         "predicate": "win",
#         "object": "set"
#       },
#       {
#         "subject": "Heliovaara",
#         "predicate": "reach",
#         "object": "semi"
#       },
#       {
#         "subject": "which",
#         "predicate": "make",
#         "object": "progress"
#       },
#       {
#         "subject": "ATP",
#         "predicate": "make",
#         "object": "progress"
#       },
#       {
#         "subject": "Woods",
#         "predicate": "lead",
#         "object": "tributes"
#       },
#       {
#         "subject": "face",
#         "predicate": "change",
#         "object": "everything"
#       },
#       {
#         "subject": "that",
#         "predicate": "win",
#         "object": "McIlroy"
#       },
#       {
#         "subject": "McIlroy",
#         "predicate": "complete",
#         "object": "Slam"
#       },
#       {
#         "subject": "McIlroy",
#         "predicate": "complete",
#         "object": "Slam"
#       },
#       {
#         "subject": "Kevin",
#         "predicate": "have",
#         "object": "what"
#       },
#       {
#         "subject": "Pimblett",
#         "predicate": "stop",
#         "object": "Chandler"
#       },
#       {
#         "subject": "who",
#         "predicate": "stop",
#         "object": "Leinster"
#       },
#       {
#         "subject": "Salah",
#         "predicate": "turn",
#         "object": "rise"
#       }
#     ]
#   },
#   {
#     "title": "Chelsea spend most on agents for second successive year",
#     "entities": [
#       {
#         "entity": "Todd Boehly",
#         "label": "PER"
#       },
#       {
#         "entity": "Chelsea",
#         "label": "PER"
#       },
#       {
#         "entity": "Premier League",
#         "label": "MISC"
#       },
#       {
#         "entity": "Chelsea",
#         "label": "ORG"
#       },
#       {
#         "entity": "Football Assocationhas",
#         "label": "ORG"
#       },
#       {
#         "entity": "English",
#         "label": "MISC"
#       },
#       {
#         "entity": "Chelsea",
#         "label": "PER"
#       },
#       {
#         "entity": "Premier League",
#         "label": "MISC"
#       },
#       {
#         "entity": "Manchester City",
#         "label": "ORG"
#       },
#       {
#         "entity": "Manchester United",
#         "label": "ORG"
#       },
#       {
#         "entity": "Aston Villa",
#         "label": "PER"
#       },
#       {
#         "entity": "Newcastle",
#         "label": "ORG"
#       },
#       {
#         "entity": "Premier League",
#         "label": "MISC"
#       },
#       {
#         "entity": "Arsenal",
#         "label": "ORG"
#       },
#       {
#         "entity": "Liverpool",
#         "label": "ORG"
#       },
#       {
#         "entity": "West Ham",
#         "label": "PER"
#       },
#       {
#         "entity": "Tottenham",
#         "label": "PER"
#       },
#       {
#         "entity": "Brighton",
#         "label": "PER"
#       },
#       {
#         "entity": "Ipswich Town",
#         "label": "PER"
#       },
#       {
#         "entity": "Premier League",
#         "label": "MISC"
#       },
#       {
#         "entity": "Leeds United",
#         "label": "ORG"
#       },
#       {
#         "entity": "Daniel Farke",
#         "label": "PER"
#       },
#       {
#         "entity": "\u00a3",
#         "label": "MISC"
#       },
#       {
#         "entity": "Burnley",
#         "label": "PER"
#       },
#       {
#         "entity": "Super League",
#         "label": "MISC"
#       },
#       {
#         "entity": "Chelsea",
#         "label": "PER"
#       },
#       {
#         "entity": "Manchester City",
#         "label": "ORG"
#       },
#       {
#         "entity": "WSL",
#         "label": "ORG"
#       },
#       {
#         "entity": "Sonia Bompastor",
#         "label": "ORG"
#       },
#       {
#         "entity": "Chelsea",
#         "label": "PER"
#       },
#       {
#         "entity": "Marko",
#         "label": "PER"
#       },
#       {
#         "entity": "McIlroy Modric",
#         "label": "LOC"
#       },
#       {
#         "entity": "Swansea",
#         "label": "ORG"
#       },
#       {
#         "entity": "Belinda",
#         "label": "ORG"
#       },
#       {
#         "entity": "Directed",
#         "label": "PER"
#       },
#       {
#         "entity": "Sam Mendes",
#         "label": "PER"
#       },
#       {
#         "entity": "Australian",
#         "label": "MISC"
#       },
#       {
#         "entity": "McIlroy McIlroy",
#         "label": "PER"
#       },
#       {
#         "entity": "VideoMcIlroy",
#         "label": "ORG"
#       },
#       {
#         "entity": "Corner",
#         "label": "PER"
#       },
#       {
#         "entity": "Delap",
# ...
#         "predicate": "pursue",
#         "object": "target"
#       },
#       {
#         "subject": "declaration",
#         "predicate": "make",
#         "object": "game"
#       },
#       {
#         "subject": "they",
#         "predicate": "do",
#         "object": "it"
#       },
#       {
#         "subject": "Warwickshire",
#         "predicate": "target",
#         "object": "339"
#       },
#       {
#         "subject": "Hants",
#         "predicate": "need",
#         "object": "over"
#       },
#       {
#         "subject": "Surrey",
#         "predicate": "put",
#         "object": "fielder"
#       },
#       {
#         "subject": "Prest",
#         "predicate": "keep",
#         "object": "strike"
#       },
#       {
#         "subject": "Bailey",
#         "predicate": "pick",
#         "object": "injury"
#       },
#       {
#         "subject": "He",
#         "predicate": "see",
#         "object": "over"
#       },
#       {
#         "subject": "Warwickshire",
#         "predicate": "target",
#         "object": "339"
#       },
#       {
#         "subject": "Booth",
#         "predicate": "work",
#         "object": "single"
#       },
#       {
#         "subject": "ball",
#         "predicate": "find",
#         "object": "edge"
#       },
#       {
#         "subject": "they",
#         "predicate": "have",
#         "object": "slip"
#       },
#       {
#         "subject": "Hants",
#         "predicate": "get",
#         "object": "four"
#       },
#       {
#         "subject": "Warwickshire",
#         "predicate": "target",
#         "object": "339"
#       },
#       {
#         "subject": "target",
#         "predicate": "make",
#         "object": "stop"
#       },
#       {
#         "subject": "Robinson",
#         "predicate": "stop",
#         "object": "byes"
#       },
#       {
#         "subject": "Potts",
#         "predicate": "beat",
#         "object": "edge"
#       },
#       {
#         "subject": "Hartleytries",
#         "predicate": "leave",
#         "object": "ball"
#       },
#       {
#         "subject": "Warwickshire",
#         "predicate": "target",
#         "object": "339"
#       },
#       {
#         "subject": "target",
#         "predicate": "run",
#         "object": "ball"
#       },
#       {
#         "subject": "who",
#         "predicate": "have",
#         "object": "4"
#       },
#       {
#         "subject": "Booth",
#         "predicate": "block",
#         "object": "ball"
#       },
#       {
#         "subject": "he",
#         "predicate": "defend",
#         "object": "it"
#       },
#       {
#         "subject": "Bamber",
#         "predicate": "see",
#         "object": "over"
#       },
#       {
#         "subject": "Potts",
#         "predicate": "take",
#         "object": "ball"
#       },
#       {
#         "subject": "Guest",
#         "predicate": "take",
#         "object": "single"
#       },
#       {
#         "subject": "He",
#         "predicate": "face",
#         "object": "balls"
#       },
#       {
#         "subject": "Warwickshire",
#         "predicate": "target",
#         "object": "339"
#       },
#       {
#         "subject": "ball",
#         "predicate": "beat",
#         "object": "fielder"
#       },
#       {
#         "subject": "Bamber",
#         "predicate": "collect",
#         "object": "singles"
#       },
#       {
#         "subject": "Warwickshire",
#         "predicate": "target",
#         "object": "339"
#       },
#       {
#         "subject": "They",
#         "predicate": "do",
#         "object": "job"
#       },
#       {
#         "subject": "he",
#         "predicate": "loop",
#         "object": "catch"
#       },
#       {
#         "subject": "who",
#         "predicate": "get",
#         "object": "swing"
#       },
#       {
#         "subject": "he",
#         "predicate": "jab",
#         "object": "ball"
#       },
#       {
#         "subject": "we",
#         "predicate": "get",
#         "object": "draw"
#       },
#       {
#         "subject": "b",
#         "predicate": "target",
#         "object": "339"
#       },
#       {
#         "subject": "Ali",
#         "predicate": "see",
#         "object": "situation"
#       },
#       {
#         "subject": "Doggett",
#         "predicate": "tempt",
#         "object": "him"
#       },
#       {
#         "subject": "he",
#         "predicate": "flash",
#         "object": "edge"
#       },
#       {
#         "subject": "you",
#         "predicate": "love",
#         "object": "cricket"
#       },
#       {
#         "subject": "AudioNottinghamshire",
#         "predicate": "listen",
#         "object": "live"
#       },
#       {
#         "subject": "Listen",
#         "predicate": "live",
#         "object": "Gloucestershire"
#       },
#       {
#         "subject": "v",
#         "predicate": "live",
#         "object": "\u00a9"
#       }
#     ]
#   },
#   {
#     "title": "Bayindir's failed Man Utd audition offers Onana dilemma",
#     "entities": [
#       {
#         "entity": "Man Utd",
#         "label": "MISC"
#       },
#       {
#         "entity": "Murphy It",
#         "label": "PER"
#       },
#       {
#         "entity": "Manchester United",
#         "label": "ORG"
#       },
#       {
#         "entity": "Ruben Amorim",
#         "label": "PER"
#       },
#       {
#         "entity": "Andre Onana",
#         "label": "PER"
#       },
#       {
#         "entity": "Newcastle",
#         "label": "ORG"
#       },
#       {
#         "entity": "Portuguese",
#         "label": "MISC"
#       },
#       {
#         "entity": "Altay Bayindir",
#         "label": "PER"
#       },
#       {
#         "entity": "St James",
#         "label": "LOC"
#       },
#       {
#         "entity": "Turkey",
#         "label": "LOC"
#       },
#       {
#         "entity": "Newcastle",
#         "label": "ORG"
#       },
#       {
#         "entity": "Amorim",
#         "label": "PER"
#       },
#       {
#         "entity": "Europa League",
#         "label": "MISC"
#       },
#       {
#         "entity": "Lyon",
#         "label": "ORG"
#       },
#       {
#         "entity": "United",
#         "label": "ORG"
#       },
#       {
#         "entity": "Amorim",
#         "label": "ORG"
#       },
#       {
#         "entity": "Onana",
#         "label": "LOC"
#       },
#       {
#         "entity": "Bayindir",
#         "label": "LOC"
#       },
#       {
#         "entity": "Altay Bayindir",
#         "label": "PER"
#       },
#       {
#         "entity": "Newcastle",
#         "label": "ORG"
#       },
#       {
#         "entity": "Onana",
#         "label": "LOC"
#       },
#       {
#         "entity": "Newcastle",
#         "label": "ORG"
#       },
#       {
#         "entity": "United",
#         "label": "ORG"
#       },
#       {
#         "entity": "Manchester United",
#         "label": "ORG"
#       },
#       {
#         "entity": "Roy Keane",
#         "label": "PER"
#       },
#       {
#         "entity": "Amorim",
#         "label": "ORG"
#       },
#       {
#         "entity": "Cameroon",
#         "label": "LOC"
#       },
#       {
#         "entity": "Onana",
#         "label": "LOC"
#       },
#       {
#         "entity": "OK",
#         "label": "ORG"
#       },
#       {
#         "entity": "Premier League",
#         "label": "MISC"
#       },
#       {
#         "entity": "United",
#         "label": "ORG"
#       },
#       {
#         "entity": "Keane",
#         "label": "PER"
#       },
#       {
#         "entity": "Sky Sports",
#         "label": "ORG"
#       },
#       {
#         "entity": "Onana",
#         "label": "PER"
#       },
#       {
#         "entity": "Lyon",
#         "label": "ORG"
#       },
#       {
#         "entity": "Premier League",
#         "label": "MISC"
#       },
#       {
#         "entity": "England",
#         "label": "LOC"
#       },
#       {
#         "entity": "Paul Robinson",
#         "label": "PER"
#       },
#       {
#         "entity": "Live",
#         "label": "ORG"
#       },
#       {
#         "entity": "Manchester United",
#         "label": "ORG"
#       },
#       {
#         "entity": "Newcastle",
#         "label": "ORG"
#       },
#       {
#         "entity": "Man Utd",
#         "label": "PER"
#       },
#       {
#         "entity": "Onana",
#         "label": "LOC"
#       },
#       {
#         "entity": "Man Utd",
#         "label": "MISC"
#       },
#       {
#         "entity": "Matic",
#         "label": "MISC"
#       },
#       {
#         "entity": "Ruben Amorim",
#         "label": "PER"
#       },
#       {
#         "entity": "Manchester United",
#         "label": "ORG"
#       },
#       {
#         "entity": "Amorim",
#         "label": "ORG"
#       },
#       {
#         "entity": "Onana",
#         "label": "LOC"
#       },
#       {
#         "entity": "Bayindir",
#         "label": "PER"
#       },
#       {
#         "entity": "Fenerbahce",
#         "label": "ORG"
#       },
#       {
#         "entity": "Premier League",
#         "label": "MISC"
#       },
#       {
#         "entity": "Newcastle",
#         "label": "ORG"
#       },
#       {
#         "entity": "Newcastle",
#         "label": "ORG"
#       },
#       {
#         "entity": "Bayindir",
#         "label": "PER"
#       },
#       {
#         "entity": "Joelinton",
#         "label": "PER"
#       },
#       {
#         "entity": "Bruno Guimaraes",
#         "label": "PER"
#       },
#       {
#         "entity": "Newcastle",
#         "label": "ORG"
#       },
#       {
#         "entity": "Onana",
#         "label": "LOC"
#       },
#       {
#         "entity": "Amorim",
#         "label": "ORG"
#       },
#       {
#         "entity": "Inter Milan",
#         "label": "ORG"
#       },
#       {
#         "entity": "Newcastle",
#         "label": "ORG"
#       },
#       {
#         "entity": "Lyon",
#         "label": "ORG"
#       },
#       {
#         "entity": "United",
#         "label": "ORG"
#       },
#       {
#         "entity": "Champions League",
#         "label": "MISC"
#       },
#       {
#         "entity": "Portuguese",
#         "label": "MISC"
#       },
#       {
#         "entity": "Onana",
#         "label": "PER"
#       },
#       {
#         "entity": "Amorim",
#         "label": "PER"
#       },
#       {
#         "entity": "Onana",
#         "label": "LOC"
#       },
#       {
#         "entity": "Lyon",
#         "label": "ORG"
#       },
#       {
#         "entity": "Tottenham",
#         "label": "ORG"
#       },
#       {
#         "entity": "Manchester United",
#         "label": "ORG"
#       },
#       {
#         "entity": "Get Man Utd",
#         "label": "ORG"
#       },
#       {
#         "entity": "Marko",
#         "label": "PER"
#       },
#       {
#         "entity": "McIlroy Modric",
#         "label": "LOC"
#       },
#       {
#         "entity": "Swansea",
#         "label": "ORG"
#       },
#       {
#         "entity": "Belinda",
#         "label": "ORG"
#       },
#       {
#         "entity": "Directed",
#         "label": "PER"
#       },
#       {
#         "entity": "Sam Mendes",
#         "label": "PER"
#       },
#       {
#         "entity": "Australian",
#         "label": "MISC"
#       },
#       {
#         "entity": "McIlroy McIlroy",
#         "label": "PER"
#       },
#       {
#         "entity": "VideoMcIlroy",
#         "label": "ORG"
#       },
#       {
#         "entity": "Corner",
#         "label": "PER"
#       },
#       {
#         "entity": "Delap",
#         "label": "ORG"
#       },
#       {
#         "entity": "McIlroy",
#         "label": "ORG"
#       },
#       {
#         "entity": "Masters Can Swiatek",
#         "label": "ORG"
#       },
#       {
#         "entity": "Alcaraz",
#         "label": "ORG"
#       },
#       {
#         "entity": "McIlroy",
#         "label": "PER"
#       },
#       {
#         "entity": "Poppy",
#         "label": "PER"
#       },
#       {
#         "entity": "VideoMcIlroy",
#         "label": "ORG"
#       },
#       {
#         "entity": "Poppy Bayindir",
#         "label": "PER"
#       },
#       {
#         "entity": "Man Utd",
#         "label": "MISC"
#       },
#       {
#         "entity": "Onana",
#         "label": "LOC"
#       },
#       {
#         "entity": "Hibs Scotland",
#         "label": "PER"
#       },
#       {
#         "entity": "Rory McIlroy",
#         "label": "PER"
#       },
#       {
#         "entity": "Grand Slam",
#         "label": "MISC"
#       },
#       {
#         "entity": "AudioRory McIlroy",
#         "label": "PER"
#       },
#       {
#         "entity": "Grand Slam",
#         "label": "MISC"
#       },
#       {
#         "entity": "Newcastle",
#         "label": "ORG"
#       },
#       {
#         "entity": "Howe What's",
#         "label": "MISC"
#       },
#       {
#         "entity": "Man City",
#         "label": "LOC"
#       },
#       {
#         "entity": "Kevin",
#         "label": "PER"
#       },
#       {
#         "entity": "De Bruyne",
#         "label": "PER"
#       },
#       {
#         "entity": "Dominant Pimblett",
#         "label": "PER"
#       },
#       {
#         "entity": "Chandler",
#         "label": "PER"
#       },
#       {
#         "entity": "UFC",
#         "label": "ORG"
#       },
#       {
#         "entity": "England",
#         "label": "LOC"
#       },
#       {
#         "entity": "Leinster",
#         "label": "ORG"
#       },
#       {
#         "entity": "Europe",
#         "label": "LOC"
#       },
#       {
#         "entity": "Salah",
#         "label": "PER"
#       },
#       {
#         "entity": "Saudi",
#         "label": "MISC"
#       },
#       {
#         "entity": "Liverpool",
#         "label": "ORG"
#       },
#       {
#         "entity": "Explainer",
#         "label": "PER"
#       },
#       {
#         "entity": "Semi",
#         "label": "PER"
#       },
#       {
#         "entity": "Premier League The",
#         "label": "MISC"
#       },
#       {
#         "entity": "Wrexham Deadpool",
#         "label": "MISC"
#       },
#       {
#         "entity": "Mullin",
#         "label": "LOC"
#       },
#       {
#         "entity": "Lamine Yamal",
#         "label": "MISC"
#       },
#       {
#         "entity": "Lamine Yamal Copyright",
#         "label": "ORG"
#       }
#     ],
#     "relations": [
#       {
#         "subject": "goalkeeper",
#         "predicate": "conundrum",
#         "object": "problem"
#       },
#       {
#         "subject": "Bayindir",
#         "predicate": "concede",
#         "object": "goals"
#       },
#       {
#         "subject": "We",
#         "predicate": "do",
#         "object": "lot"
#       },
#       {
#         "subject": "Amorim",
#         "predicate": "face",
#         "object": "decision"
#       },
#       {
#         "subject": "Bayindir",
#         "predicate": "make",
#         "object": "debut"
#       },
#       {
#         "subject": "Keane",
#         "predicate": "tell",
#         "object": "Sports"
#       },
#       {
#         "subject": "keeper",
#         "predicate": "make",
#         "object": "mistakes"
#       },
#       {
#         "subject": "Robinson",
#         "predicate": "tell",
#         "object": "Live"
#       },
#       {
#         "subject": "you",
#         "predicate": "touch",
#         "object": "ball"
#       },
#       {
#         "subject": "you",
#         "predicate": "need",
#         "object": "rest"
#       },
#       {
#         "subject": "Newcastle",
#         "predicate": "beat",
#         "object": "Utd"
#       },
#       {
#         "subject": "you",
#         "predicate": "drop",
#         "object": "keeper"
#       },
#       {
#         "subject": "He",
#         "predicate": "attempt",
#         "object": "passes"
#       },
#       {
#         "subject": "Bayindir",
#         "predicate": "attempt",
#         "object": "pass"
#       },
#       {
#         "subject": "Guimaraes",
#         "predicate": "add",
#         "object": "goal"
#       },
#       {
#         "subject": "Onana",
#         "predicate": "make",
#         "object": "errors"
#       },
#       {
#         "subject": "Portuguese",
#         "predicate": "give",
#         "object": "nothing"
#       },
#       {
#         "subject": "he",
#         "predicate": "recall",
#         "object": "Onana"
#       },
#       {
#         "subject": "You",
#         "predicate": "take",
#         "object": "him"
#       },
#       {
#         "subject": "Woods",
#         "predicate": "lead",
#         "object": "tributes"
#       },
#       {
#         "subject": "face",
#         "predicate": "change",
#         "object": "everything"
#       },
#       {
#         "subject": "that",
#         "predicate": "win",
#         "object": "McIlroy"
#       },
#       {
#         "subject": "McIlroy",
#         "predicate": "complete",
#         "object": "Slam"
#       },
#       {
#         "subject": "McIlroy",
#         "predicate": "complete",
#         "object": "Slam"
#       },
#       {
#         "subject": "Kevin",
#         "predicate": "have",
#         "object": "what"
#       },
#       {
#         "subject": "Pimblett",
#         "predicate": "stop",
#         "object": "Chandler"
#       },
#       {
#         "subject": "who",
#         "predicate": "stop",
#         "object": "Leinster"
#       },
#       {
#         "subject": "Salah",
#         "predicate": "turn",
#         "object": "rise"
#       }
#     ]
#   }
# ]

# %%
# Build the knowledge graph
knowledge_graph = build_knowledge_graph(processed_data)
# Out:
# The graph contains 713 triples.

# %% [markdown]
# # PART 2

# %% [markdown]
# ##### Basic embedding pipeline

# %% [markdown]
# Our graph is an RDFLib object and TriplesFactory expect a NumPy array so we have to convert our graph before the embedding

# %%
knowledge_graph = Graph()
knowledge_graph.parse("knowledge_graph.ttl", format="turtle")
# Out:
# <Graph identifier=Nfadf85a5f99e4601b7bc16b02a421361 (<class 'rdflib.graph.Graph'>)>

# %%
# Convert RDFLib graph triples to a list of lists
triples = [(str(s), str(p), str(o)) for s, p, o in knowledge_graph]

# Convert the list of lists to a NumPy array
triples_array = np.array(triples)

tf = TriplesFactory.from_labeled_triples(triples_array)
tf
# Out:
# TriplesFactory(num_entities=669, num_relations=135, create_inverse_triples=False, num_triples=713)

# %%
# Split your triples into training (90%) and test (10%)
# We wanted to include the validation, but it gave us a coverage error.
training, testing = tf.split([0.9, 0.1])

print(f"Training triples: {training.num_triples}") 
print(f"Testing triples: {testing.num_triples}")
# Out:
# WARNING:pykeen.utils:using automatically assigned random_state=2131556745
# INFO:pykeen.triples.splitting:done splitting triples to groups of sizes [54, 72]
# Training triples: 641
# Testing triples: 72

# %%
# Dictionary to store results 
model_results = {} 
# Test different models 
models = ['TransE', 'DistMult', 'ComplEx'] 
for model_name in models: 
    results = pipeline( 
        training=training,
        testing=testing, 
        model=model_name, 
        epochs=100, 
        model_kwargs=dict(embedding_dim=50),  # Specify embedding dimension here
        training_kwargs=dict(batch_size=32), 
        random_seed=42, 
    ) 
    model_results[model_name] = results
# Out:
# No cuda devices were available. The model runs on CPU
# Training epochs on cpu: 100%|██████████| 100/100 [00:59<00:00,  1.68epoch/s, loss=0.0714, prev_loss=0.0664]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# Evaluating on cpu:   0%|          | 0.00/72.0 [00:00<?, ?triple/s]WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# Evaluating on cpu: 100%|██████████| 72.0/72.0 [00:00<00:00, 148triple/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.57s seconds
# WARNING:pykeen.utils:No cuda devices were available. The model runs on CPU
# INFO:pykeen.pipeline.api:Using device: None
# Training epochs on cpu: 100%|██████████| 100/100 [00:58<00:00,  1.70epoch/s, loss=0.447, prev_loss=0.417]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# Evaluating on cpu:   0%|          | 0.00/72.0 [00:00<?, ?triple/s]WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# Evaluating on cpu: 100%|██████████| 72.0/72.0 [00:00<00:00, 451triple/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.19s seconds
# WARNING:pykeen.utils:No cuda devices were available. The model runs on CPU
# INFO:pykeen.pipeline.api:Using device: None
# Training epochs on cpu: 100%|██████████| 100/100 [01:23<00:00,  1.20epoch/s, loss=1.03, prev_loss=0.917]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# Evaluating on cpu:   0%|          | 0.00/72.0 [00:00<?, ?triple/s]WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# Evaluating on cpu: 100%|██████████| 72.0/72.0 [00:00<00:00, 184triple/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.43s seconds

# %% [markdown]
# ##### Evaluation

# %%
def evaluate_model(results, model_name): 
    metrics = results.metric_results.to_dict()

    # We want to evaluate both head and tail predictions with realistic strategy to be balanced
    strategy_metrics = metrics['both']['realistic']

    print(f"=== Evaluation Metrics for {model_name} ===")
    # Mean Rank Metrics
    print(f"Arithmetic Mean Rank: {strategy_metrics['arithmetic_mean_rank']:.2f}")
    print(f"Harmonic Mean Rank: {strategy_metrics['harmonic_mean_rank']:.2f}")
    # Inverse Rank Metrics
    print(f"Inverse Arithmetic Mean Rank: {strategy_metrics['inverse_arithmetic_mean_rank']:.4f}")
    print(f"Inverse Harmonic Mean Rank: {strategy_metrics['inverse_harmonic_mean_rank']:.4f}")
    # Hits@K Metrics
    print(f"Hits@3: {strategy_metrics['hits_at_3']:.2%}")
    print(f"Hits@5: {strategy_metrics['hits_at_5']:.2%}")
    print(f"Hits@10: {strategy_metrics['hits_at_10']:.2%}")

# %%
for model_name, results in model_results.items():
    evaluate_model(results, model_name)
# Out:
# === Evaluation Metrics for TransE ===
# Arithmetic Mean Rank: 203.47
# Harmonic Mean Rank: 12.61
# Inverse Arithmetic Mean Rank: 0.0049
# Inverse Harmonic Mean Rank: 0.0793
# Hits@3: 11.81%
# Hits@5: 17.36%
# Hits@10: 22.22%
# === Evaluation Metrics for DistMult ===
# Arithmetic Mean Rank: 360.06
# Harmonic Mean Rank: 114.62
# Inverse Arithmetic Mean Rank: 0.0028
# Inverse Harmonic Mean Rank: 0.0087
# Hits@3: 0.00%
# Hits@5: 0.69%
# Hits@10: 1.39%
# === Evaluation Metrics for ComplEx ===
# Arithmetic Mean Rank: 323.26
# Harmonic Mean Rank: 154.24
# Inverse Arithmetic Mean Rank: 0.0031
# Inverse Harmonic Mean Rank: 0.0065
# Hits@3: 0.00%
# Hits@5: 0.00%
# Hits@10: 0.69%

# %% [markdown]
# TransE is the best-performing model among the three:
# - Arithmetic Mean Rank (AMR):
#     - Lower is better, as it indicates that the correct entity is ranked closer to the top.
#     - TransE: 147.59 (best)
#
# - Harmonic Mean Rank (HMR):
#     - Lower is better, as it gives more weight to lower ranks.
#     - TransE: 15.88 (best)
#
# - Inverse Arithmetic Mean Rank (IAMR):
#     - Higher is better, as it reflects better ranking performance.
#     - TransE: 0.0068 (best)
#
# - Inverse Harmonic Mean Rank (IHMR):
#     - Higher is better, as it emphasizes better performance for lower ranks.
#     - TransE: 0.0630 (best)
#
# - Hits@K (Hits@3, Hits@5, Hits@10):
#     - Higher is better, as it indicates the percentage of correct predictions within the top K ranks.
#     - Hits@3:
#         - TransE: 7.26% (best)
#     - Hits@5:
#         - TransE: 10.48% (best)
#     - Hits@10:
#         - TransE: 18.55% (best)

# %% [markdown]
# Note: the metrics from above may have changed due to different testing and launching of our code. Each times, TransE in better is all of the domains shown.

# %% [markdown]
# ##### Link Prediction

# %%
for head, relation, tail in triples:
    print(f"Head: {head}, Relation: {relation}, Tail: {tail}")
# Out:
# Head: http://example.org/Hants, Relation: http://example.org/need, Tail: http://example.org/over
# Head: http://example.org/that, Relation: http://example.org/win, Tail: http://example.org/McIlroy
# Head: http://example.org/Tottenham_Hotspur, Relation: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Tail: http://example.org/PER
# Head: http://example.org/BBC_Radio_Bristol, Relation: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Tail: http://example.org/ORG
# Head: http://example.org/Rory_McIlroy, Relation: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Tail: http://example.org/PER
# Head: http://example.org/Allan_Taylor, Relation: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Tail: http://example.org/PER
# Head: http://example.org/%C2%A3, Relation: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Tail: http://example.org/MISC
# Head: http://example.org/pair, Relation: http://example.org/drop, Tail: http://example.org/him
# Head: http://example.org/BBC_Radio_Newcastle_This, Relation: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Tail: http://example.org/ORG
# Head: http://example.org/BBC_Radio_Newcastle_Bears, Relation: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Tail: http://example.org/ORG
# Head: http://example.org/Explainer, Relation: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Tail: http://example.org/PER
# Head: http://example.org/Lorenzo_Musetti%27sMonte_Carlo, Relation: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Tail: http://example.org/PER
# Head: http://example.org/OK, Relation: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Tail: http://example.org/ORG
# Head: http://example.org/World_Snooker_Championship, Relation: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Tail: http://example.org/MISC
# Head: http://example.org/Open_Championship, Relation: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Tail: http://example.org/MISC
# Head: http://example.org/Hibs_Scotland, Relation: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Tail: http://example.org/PER
# Head: http://example.org/Somerset, Relation: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Tail: http://example.org/ORG
# Head: http://example.org/expression, Relation: http://example.org/demonstrate, Tail: http://example.org/focus
# Head: http://example.org/Disney, Relation: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Tail: http://example.org/ORG
# Head: http://example.org/which, Relation: http://example.org/take, Tail: http://example.org/place
# Head: http://example.org/Masters_Can_Swiatek, Relation: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Tail: http://example.org/ORG
# Head: http://example.org/City, Relation: http://example.org/spend, Tail: http://example.org/most
# Head: http://example.org/Jurgen_Klopp, Relation: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Tail: http://example.org/PER
# Head: http://example.org/he, Relation: http://example.org/recall, Tail: http://example.org/Onana
# Head: http://example.org/includingAryna_Sabalenka, Relation: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Tail: http://example.org/ORG
# Head: http://example.org/BBC_Radio_Lancashire_Listen, Relation: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Tail: http://example.org/ORG
# Head: http://example.org/Doggett, Relation: http://example.org/tempt, Tail: http://example.org/him
# Head: http://example.org/Pogacar, Relation: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Tail: http://example.org/PER
# Head: http://example.org/he, Relation: http://example.org/tell, Tail: http://example.org/champion
# Head: http://example.org/Football_Assocationhas, Relation: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Tail: http://example.org/ORG
# Head: http://example.org/Roy_Keane, Relation: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Tail: http://example.org/PER
# Head: http://example.org/Arsenal, Relation: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Tail: http://example.org/ORG
# Head: http://example.org/he, Relation: http://example.org/have, Tail: http://example.org/will
# Head: http://example.org/He, Relation: http://example.org/have, Tail: http://example.org/swing
# Head: http://example.org/Sergio_Garcia, Relation: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Tail: http://example.org/PER
# Head: http://example.org/ball, Relation: http://example.org/find, Tail: http://example.org/edge
# Head: http://example.org/League_One, Relation: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Tail: http://example.org/MISC
# Head: http://example.org/Durham_Emilio_Gay, Relation: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Tail: http://example.org/ORG
# Head: http://example.org/GP, Relation: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Tail: http://example.org/ORG
# Head: http://example.org/he, Relation: http://example.org/become, Tail: http://example.org/player
# Head: http://example.org/Warwickshire, Relation: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Tail: http://example.org/ORG
# Head: http://example.org/Tom_Hartley, Relation: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Tail: http://example.org/PER
# Head: http://example.org/Leicestershire, Relation: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Tail: http://example.org/ORG
# Head: http://example.org/it, Relation: http://example.org/require, Tail: http://example.org/way
# Head: http://example.org/I, Relation: http://example.org/know, Tail: http://example.org/Harry
# Head: http://example.org/Trent, Relation: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Tail: http://example.org/PER
# Head: http://example.org/Munich_Open, Relation: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Tail: http://example.org/MISC
# Head: http://example.org/Destiny_Udogie, Relation: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Tail: http://example.org/ORG
# Head: http://example.org/Raducanuis, Relation: http://example.org/turn, Tail: http://example.org/Petchy
# Head: http://example.org/he, Relation: http://example.org/win, Tail: http://example.org/Jacket
# Head: http://example.org/nobody, Relation: http://example.org/copy, Tail: http://example.org/technique
# Head: http://example.org/Division_One, Relation: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Tail: http://example.org/MISC
# Head: http://example.org/Chelsea, Relation: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Tail: http://example.org/ORG
# Head: http://example.org/Barry, Relation: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Tail: http://example.org/PER
# Head: http://example.org/old, Relation: http://example.org/become, Tail: http://example.org/man
# Head: http://example.org/he, Relation: http://example.org/fumble, Tail: http://example.org/chance
# Head: http://example.org/AudioSurrey, Relation: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Tail: http://example.org/ORG
# Head: http://example.org/who, Relation: http://example.org/get, Tail: http://example.org/swing
# Head: http://example.org/Alcaraz, Relation: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Tail: http://example.org/ORG
# Head: http://example.org/Liverpool, Relation: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Tail: http://example.org/ORG
# Head: http://example.org/Pimblett, Relation: http://example.org/stop, Tail: http://example.org/Chandler
# Head: http://example.org/Cameroon, Relation: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Tail: http://example.org/LOC
# Head: http://example.org/Surrey, Relation: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Tail: http://example.org/ORG
# Head: http://example.org/Tom_Prest, Relation: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Tail: http://example.org/PER
# Head: http://example.org/whileGiles_Husseytriumphed, Relation: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Tail: http://example.org/PER
# Head: http://example.org/Gloucestershire, Relation: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Tail: http://example.org/ORG
# Head: http://example.org/AudioNottinghamshire, Relation: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Tail: http://example.org/ORG
# Head: http://example.org/Augusta, Relation: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Tail: http://example.org/LOC
# Head: http://example.org/McIlroy%E2%80%99s, Relation: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Tail: http://example.org/ORG
# Head: http://example.org/Rory_McIlroy, Relation: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Tail: http://example.org/MISC
# Head: http://example.org/
Relation: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Tail: http://example.org/PER
# Head: http://example.org/Methods, Relation: http://example.org/include, Tail: http://example.org/Zootopia
# Head: http://example.org/Comments, Relation: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Tail: http://example.org/ORG
# Head: http://example.org/Page, Relation: http://example.org/rack, Tail: http://example.org/maximum
# Head: http://example.org/he, Relation: http://example.org/miss, Tail: http://example.org/cut
# Head: http://example.org/mid-2010s, Relation: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Tail: http://example.org/MISC
# Head: http://example.org/Prest, Relation: http://example.org/keep, Tail: http://example.org/strike
# Head: http://example.org/Swansea, Relation: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Tail: http://example.org/PER
# Head: http://example.org/Andy_Coleman, Relation: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Tail: http://example.org/PER
# Head: http://example.org/Brett_Cravatt, Relation: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Tail: http://example.org/PER
# Head: http://example.org/Luke_Wellsis, Relation: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Tail: http://example.org/PER
# Head: http://example.org/they, Relation: http://example.org/throw, Tail: http://example.org/what
# Head: http://example.org/Prest, Relation: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Tail: http://example.org/LOC
# Head: http://example.org/Rose, Relation: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Tail: http://example.org/LOC
# Head: http://example.org/Poppy, Relation: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Tail: http://example.org/LOC
# Head: http://example.org/Harry, Relation: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Tail: http://example.org/PER
# Head: http://example.org/who, Relation: http://example.org/stop, Tail: http://example.org/Leinster
# Head: http://example.org/Arne_Slot, Relation: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Tail: http://example.org/PER
# Head: http://example.org/triangle, Relation: http://example.org/become, Tail: http://example.org/four
# Head: http://example.org/he, Relation: http://example.org/have, Tail: http://example.org/beer
# Head: http://example.org/England, Relation: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Tail: http://example.org/LOC
# Head: http://example.org/Clay, Relation: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Tail: http://example.org/PER

# %% [markdown]
# From the triples shown above, we will try testing with:
#
# Head: http://example.org/he, Relation: http://example.org/have, Tail: http://example.org/beer

# %%
def predict_tail_entities(model, triples_factory, head, relation, k=5):
    # Convert head and relation to their corresponding indices
    head_idx = triples_factory.entity_to_id[head]
    relation_idx = triples_factory.relation_to_id[relation]
    print(f"Head Index: {head_idx}, Relation Index: {relation_idx}")
    # Create the hrt_batch for prediction
    hrt_batch = torch.tensor([[head_idx, relation_idx, 0]])  # Tail is set to 0 as a placeholder

    # Get scores for all possible tails
    scores = model.predict(hrt_batch, target="tail")

    # Get the top k predictions
    top_tails = torch.topk(scores, k=k, dim=1)

    # Map indices back to entity labels
    return [
        (triples_factory.entity_id_to_label[idx.item()], score.item())
        for idx, score in zip(top_tails.indices[0], top_tails.values[0])
    ]

# %%
head_pred = "http://example.org/he"
relation_pred = "http://example.org/have"
predict_tail_entities(model_results['TransE'].model, tf, head_pred, relation_pred, k=5)
# Out:
# Head Index: 537, Relation Index: 55
# [('http://example.org/he', -6.242888450622559),
#  ('http://example.org/beer', -6.53448486328125),
#  ('http://example.org/enough', -6.921862602233887),
#  ('http://example.org/range', -7.064138412475586),
#  ('http://example.org/will', -7.352336406707764)]

# %% [markdown]
# The prediction is good as "beer" ranked 2nd in the prediction behind "he" which actually is the head. This probably happens because of a bias.

# %% [markdown]
# Next we are testing another triple :
#
# Head: http://example.org/Hants, Relation: http://example.org/need, Tail: http://example.org/over

# %%
head_pred2 = "http://example.org/Hants"
relation_pred2 = "http://example.org/need"
predict_tail_entities(model_results['TransE'].model, tf, head_pred2, relation_pred2, k=5)
# Out:
# Head Index: 189, Relation Index: 80
# [('http://example.org/Hants', -5.752021789550781),
#  ('http://example.org/Joe_Allen', -6.774236679077148),
#  ('http://example.org/Welshmanhad', -6.853548526763916),
#  ('http://example.org/period', -7.117976665496826),
#  ('http://example.org/media', -7.136225700378418)]

# %% [markdown]
# in the top 5 predictions we do not see the expected tail "over". This is probably due to the triple not being a good one as it does not really makes sens. On the other hand, the predictions makes more sens in term of meaning. We can thus conclude that our model is pretty good.

# %% [markdown]
# ##### Data augmentation
