# %%
import re
import json
import spacy
import nltk
import requests
import sklearn_crfsuite
from bs4 import BeautifulSoup
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from datasets import load_dataset
from sklearn_crfsuite import metrics
from seqeval.metrics import classification_report, accuracy_score, precision_score, f1_score
from rdflib import Graph, URIRef, Literal, Namespace
from rdflib.namespace import RDF, RDFS
import urllib.parse

# %%
nltk.download("punkt")
nltk.download("stopwords")
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\rafro\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\rafro\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\rafro\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# # === PART 1 ===

# %% [markdown]
# ## TASK 1: MODEL FOR NER

# %% [markdown]
# ### 1. TEXT CLEANING & PREPROCESSING

# %%
def clean_text(text):
    text = re.sub(r"<.*?>", "", text)
    text = re.sub(r"[^a-zA-Z0-9 ]", "", text)
    text = text.lower()
    words = word_tokenize(text)
    words = [w for w in words if w not in stopwords.words("english")]
    lemmatizer = WordNetLemmatizer()
    words = [lemmatizer.lemmatize(w) for w in words]
    return " ".join(words)

# %%
raw_text = "<p>Apple was founded by Steve Jobs.</p>"
cleaned_text = clean_text(raw_text)
print("Cleaned Text:", cleaned_text)
# Out:
# Cleaned Text: apple founded steve job

# %% [markdown]
# ### 2. NAMED ENTITY RECOGNITION (NER)

# %%
# Load the CoNLL-2003 dataset 
dataset = load_dataset("conll2003", trust_remote_code=True)
train_dataset = dataset['train'] 
validation_dataset = dataset['validation'] 
test_dataset = dataset['test'] 
# Example: Print the first example from the training set 
print(train_dataset[0])
# Out:
# {'id': '0', 'tokens': ['EU', 'rejects', 'German', 'call', 'to', 'boycott', 'British', 'lamb', '.'], 'pos_tags': [22, 42, 16, 21, 35, 37, 16, 21, 7], 'chunk_tags': [11, 21, 11, 12, 21, 22, 11, 12, 0], 'ner_tags': [3, 0, 7, 0, 0, 0, 7, 0, 0]}

# %%
# Map NER tag indices to actual labels
ner_labels = dataset["train"].features["ner_tags"].feature.int2str
print(ner_labels)
# Out:
# <bound method ClassLabel.int2str of ClassLabel(names=['O', 'B-PER', 'I-PER', 'B-ORG', 'I-ORG', 'B-LOC', 'I-LOC', 'B-MISC', 'I-MISC'], id=None)>

# %%
# Feature Extraction for CRF Model
def extract_features(doc):
    return [{"word": w} for w in doc["tokens"]]

def get_labels(doc):
    return [ner_labels(label) for label in doc["ner_tags"]]

# %%
X_train = [extract_features(sent) for sent in train_dataset]
y_train = [get_labels(sent) for sent in train_dataset]
X_test = [extract_features(sent) for sent in test_dataset]
y_test = [get_labels(sent) for sent in test_dataset]

print("Sample Features:", X_train[0])
print("Sample Labels:", y_train[0])
# Out:
# Sample Features: [{'word': 'EU'}, {'word': 'rejects'}, {'word': 'German'}, {'word': 'call'}, {'word': 'to'}, {'word': 'boycott'}, {'word': 'British'}, {'word': 'lamb'}, {'word': '.'}]
# Sample Labels: ['B-ORG', 'O', 'B-MISC', 'O', 'O', 'O', 'B-MISC', 'O', 'O']

# %%
# Train CRF model
crf = sklearn_crfsuite.CRF(
    algorithm="lbfgs",
    c1=0.1,
    c2=0.1,
    max_iterations=100,
    all_possible_transitions=False
)
crf.fit(X_train, y_train)
# Out:
# CRF(algorithm='lbfgs', all_possible_transitions=False, c1=0.1, c2=0.1,
#     max_iterations=100)

# %%
# Evaluate CRF model
y_pred = crf.predict(X_test)

# %%
nlp = spacy.load("en_ner_conll03")

# Convert spaCy predictions to IOB format aligned with test set
def spacy_ner_predict(sentences):
    y_preds = []
    for sent in sentences:
        doc = nlp(" ".join(sent["tokens"]))
        pred_tags = ["O"] * len(sent["tokens"])
        for ent in doc.ents:
            start, end, label = ent.start, ent.end, ent.label_
            if start < len(pred_tags):
                pred_tags[start] = f"B-{label}"
                for i in range(start+1, min(end, len(pred_tags))):
                    pred_tags[i] = f"I-{label}"
        y_preds.append(pred_tags)
    return y_preds

# Get gold labels from test set
ner_labels = dataset["train"].features["ner_tags"].feature.int2str
y_true = [[ner_labels(tag) for tag in sent["ner_tags"]] for sent in test_dataset]
# Out:
# C:\Users\rafro\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\spacy\util.py:910: UserWarning: [W095] Model 'en_pipeline' (0.0.0) was trained with spaCy v3.7.5 and may not be 100% compatible with the current version (3.8.4). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %%
# Evaluate spaCy predictions
y_pred_spacy = spacy_ner_predict(test_dataset)

# %%
# Compare CRF and spaCy predictions
print("📊 CRF Classification Report:")
print(metrics.flat_classification_report(y_test, y_pred))
print("📊 spaCy Classification Report:")
print(classification_report(y_true, y_pred_spacy))
# Out:
# 📊 CRF Classification Report:
#               precision    recall  f1-score   support
#
#        B-LOC       0.89      0.78      0.83      1668
#       B-MISC       0.83      0.67      0.74       702
#        B-ORG       0.81      0.55      0.66      1661
#        B-PER       0.74      0.43      0.55      1617
#        I-LOC       0.42      0.66      0.51       257
#       I-MISC       0.63      0.60      0.61       216
#        I-ORG       0.53      0.63      0.58       835
#        I-PER       0.72      0.55      0.62      1156
#            O       0.94      0.97      0.95     38323
#
#     accuracy                           0.91     46435
#    macro avg       0.72      0.65      0.67     46435
# weighted avg       0.90      0.91      0.90     46435
#
# 📊 spaCy Classification Report:
#               precision    recall  f1-score   support
#
#          LOC       0.69      0.64      0.66      1668
#         MISC       0.67      0.63      0.65       702
#          ORG       0.70      0.67      0.68      1661
#          PER       0.63      0.65      0.64      1617
#
#    micro avg       0.67      0.65      0.66      5648
#    macro avg       0.67      0.65      0.66      5648
# weighted avg       0.67      0.65      0.66      5648

# %% [markdown]
# 📊 Named Entity Recognition: CRF vs spaCy Pretrained Model
# | Model   | Label Format                | Notes                                               |
# |---------|-----------------------------|-----------------------------------------------------|
# | CRF     | B-LOC, I-ORG, O, etc.       | Uses BIO tagging (Begin, Inside, Outside) for token-level labeling |
# | spaCy   | LOC, PER, ORG, MISC         | Returns full entity spans, not token-level BIO tags    |
#
# Note: spaCy internally uses BILUO tags during training, but outputs clean entity spans without B-/I- prefixes. CRF evaluates per-token; spaCy evaluates per-entity.

# %% [markdown]
# 📈 Performance Comparison (weighted avrg)
# | Metric     | CRF Model (Token-level) | spaCy Pretrained (Entity-level) |
# |------------|--------------------------|----------------------------------|
# | Precision  | 0.90                     | 0.67                             |
# | Recall     | 0.91                     | 0.65                             |
# | F1-Score   | 0.90                     | 0.66                             |
#
# - The CRF model, trained specifically on the CoNLL-2003 dataset, achieves higher precision, recall, and F1-score, reflecting strong token-level performance.
#
# - The spaCy pretrained model performs reasonably well but slightly lower. Its strength lies in ease of use, span-level predictions, and pretrained generalization.
#
# - The difference is due to:
#
#     - CRF evaluates per-token BIO tags.
#
#     - spaCy evaluates entire named entity spans, which is stricter (e.g., must capture "New York City" fully).
#
# - For fine-grained, high-accuracy tasks, a CRF trained on your specific dataset is more effective.
#
# - For general-purpose NER across diverse texts, spaCy offers strong performance with zero training.

# %%
def extract_crf_entities(test_data, predictions):
    extracted = []
    for sent, tags in zip(test_data, predictions):
        tokens = sent["tokens"]
        i = 0
        while i < len(tags):
            tag = tags[i]
            if tag.startswith("B-"):
                entity = tokens[i]
                start = i
                label = tag[2:]
                i += 1
                while i < len(tags) and tags[i].startswith("I-"):
                    entity += " " + tokens[i]
                    i += 1
                end = i - 1
                extracted.append({"entity": entity, "label": label, "start": start, "end": end})
            else:
                i += 1
    return extracted

crf_entities = extract_crf_entities(test_dataset, y_pred)

# Save to JSON file
with open("crf_entities.json", "w") as f:
    json.dump(crf_entities, f, indent=2)

# %%
def extract_spacy_entities(test_data, model):
    all_entities = []
    for sent in test_data:
        tokens = sent["tokens"]
        text = " ".join(tokens)
        doc = model(text)
        for ent in doc.ents:
            all_entities.append({
                "entity": ent.text,
                "label": ent.label_,
                "start": ent.start,
                "end": ent.end - 1
            })
    return all_entities

spacy_entities = extract_spacy_entities(test_dataset, nlp)

# Save to JSON file
with open("spacy_entities.json", "w") as f:
    json.dump(spacy_entities, f, indent=2)

# %% [markdown]
# ### 3. RELATION EXTRACTION (RE)

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ------- -------------------------------- 2.4/12.8 MB 12.2 MB/s eta 0:00:01
#      -------------- ------------------------- 4.7/12.8 MB 11.9 MB/s eta 0:00:01
#      ---------------------- ----------------- 7.1/12.8 MB 11.8 MB/s eta 0:00:01
#      ------------------------------ --------- 9.7/12.8 MB 11.8 MB/s eta 0:00:01
#      ------------------------------------ -- 12.1/12.8 MB 12.0 MB/s eta 0:00:01
#      --------------------------------------- 12.8/12.8 MB 11.2 MB/s eta 0:00:00
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %% [markdown]
# The goal is to extract relations of the form (subject, predicate, object) where:
# - Subject: The entity performing the action (or passive subject).
# - Predicate: The verb that describes the action.
# - Object: The entity affected by the action (or passive agent).

# %% [markdown]
# Application of extraction rules:
# - Input Text: "Apple was founded by Steve Jobs."
# - spaCy Process: The text is processed using the spaCy NLP pipeline.
# - Subject Extraction:
#     - Token: "Apple" (dependency: nsubjpass).
#     - Recognized as the subject of the sentence.
# - Predicate Extraction:
#     - Token: "founded" (head of "Apple" and main verb of the sentence).
#     - Lemma: "found" (the base form of the verb).
# - Agent (Object of Preposition):
#     - The phrase “by Steve Jobs” is detected as a prepositional phrase.
#     - "by" is the preposition, and "Steve Jobs" is the object of the preposition (pobj).

# %%
nlp_re = spacy.load("en_core_web_sm")
txt = "Apple was founded by Steve Jobs."
doc = nlp_re(txt)
relations = []
# Iterate over tokens in the document
for token in doc:
    # Check for passive subject (nsubjpass) and the verb (ROOT)
    if token.dep_ == "nsubjpass" and token.head.pos_ == "VERB":
        subject = token.text  # Passive subject
        predicate = token.head.lemma_  # Predicate (base form of the verb)
        
        # Search for the prepositional phrase indicating the agent
        for child in token.head.children:
            if child.dep_ == "agent":  # Look for the agent (usually in 'by' phrase)
                for obj in child.children:
                    if obj.dep_ == "pobj":  # The object of the preposition (agent)
                        obj_text = obj.text
                        # Append the relation to the list
                        relations.append((subject, predicate, obj_text))
print(relations)
# Out:
# [('Apple', 'found', 'Jobs')]

# %% [markdown]
# It works well, we will implement this code in an extraction function to make it go through our test_dataset and save it.

# %%
def extract_relations(test_data, model):
    relations = []
    for sent in test_data:
        tokens = sent["tokens"]
        text = " ".join(tokens)
        doc = model(text)
        for token in doc:
            if token.dep_ == "nsubjpass" and token.head.pos_ == "VERB":
                subject = token.text
                predicate = token.head.lemma_
                for child in token.head.children:
                    if child.dep_ == "agent":
                        for agent in child.children:
                            if agent.dep_ == "pobj":
                                obj = agent.text
                                relations.append((subject, predicate, obj))
    return relations

core_web_relations = extract_relations(test_dataset, nlp_re)

# Save to JSON file
with open("core_web_relations.json", "w") as f:
    json.dump(core_web_relations, f, indent=2)

# %% [markdown]
# ### 4. KNOWLEDGE GRAPH BUILDING

# %% [markdown]
# We will work with the entities from the crf extraction, saved in crf_entities.json as well as with the relations saved in core_web_relations.json.

# %%
EX = Namespace("http://example.org/")
g = Graph()

with open("core_web_relations.json", "r") as relations_file:
    relations = json.load(relations_file)

with open("crf_entities.json", "r") as entities_file:
    entities = json.load(entities_file)

# %%
# Helper function to make entity names URI-safe
def make_uri_safe(name):
    return urllib.parse.quote(name.replace(" ", "_"))

# %% [markdown]
# This function will resolve the entities name problem as there are spaces in the .json

# %%
for relation in relations:
    subject, predicate, obj = relation

    # Add triples to the graph
    g.add((URIRef(EX[subject]), URIRef(EX[predicate]), URIRef(EX[obj])))

for entity in entities:
    entity_name = entity.get("entity", None)
    entity_label = entity.get("label", None)

    if entity_name and entity_label:
        # Make the entity name URI-safe
        safe_entity_name = make_uri_safe(entity_name)
        # Add the entity with its type (label) to the graph
        g.add((URIRef(EX[safe_entity_name]), RDF.type, URIRef(EX[entity_label])))

# %%
query = """
SELECT ?subject ?predicate ?object
WHERE {
    # ?subject ?predicate ?object .
}
"""
results = g.query(query)
for row in results:
    print(f"Subject: {row.subject}, Predicate: {row.predicate}, Object: {row.object}")
# Out:
# Subject: http://example.org/JACKSONVILLE, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/Healy, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Aleksander_Kwasniewski, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Andersson, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Marcelo, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Gabon, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/Dean_Holdsworth, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/26%3D_Michaela, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/28-1_Real_Madrid_Barcelona, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Greek, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/MISC
# Subject: http://example.org/Casey_Fitzrandolph, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/House_of_Commons, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/SHEFFIELD, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/Buenos_Aires_Newsroom, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Benjamin_Netanyahu, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/GENEVA_1996-12-06, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/Bolton, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Austrian, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/MISC
# Subject: http://example.org/Raith, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Dean_Jones, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/8-213_9-216, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Andrews, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/22._Bibiana, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Carlos_Secretario, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Michael_Cornwell, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Jim_Bolger, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/12%3D_Katharina, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Supreme_Court, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Public_Service, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Dow, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/MISC
# Subject: http://example.org/FREESTYLE_SKIING-WORLD_CUP, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/MISC
# Subject: http://example.org/12.00_9.94, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/OTTAWA, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/Darren_Garforth, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/ratification, Predicate: http://example.org/delay, Object: http://example.org/party
# Subject: http://example.org/Schalk_van_der_Merwe, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Brazilian, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/MISC
# Subject: http://example.org/Warsaw, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/Karachi, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/par-72_Chapman_Golf, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/2-7_3-125_4-146_5-170_6-190_7-195, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Bob_Halverson, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Ally_McCoist, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Caribs, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/Havel, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Gianfranco_Fini, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Roda_JC_Kerkrade, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/DETROIT, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Kilmarnock, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Nelson_Mandela, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Oats_Rye_Flaxseed_Canola_Corn, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Real_Madrid, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/J._Murray, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Bali_1996-12-07, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/WASHINGTON_1996-12-05, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/312-408_8720, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Yevgeny_Kafelnikov, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Brian_Laudrup, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Colorado_1996-12-07, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/Wall_Street_Desk, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/VfB_Stuttgart, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Weah, Predicate: http://example.org/suspend, Object: http://example.org/UEFA
# Subject: http://example.org/SANTIAGO_1996-12-05, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Ian_Healy, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/GUNMEN_KILL, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Caen, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/NATO_enlargement, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Algerian, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/MISC
# Subject: http://example.org/Partizan, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/%2A1995_totals, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/PRAGUE_1996-12-06, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/India, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/Burmese, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/MISC
# Subject: http://example.org/International_Finance_Bureau, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Norwich, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Canadian_Wheat_Board, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/LISBON_1996-12-06, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/Chris_Hunt, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Estudiantes, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Algerians, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/MISC
# Subject: http://example.org/Fabrizio_Ravanelli, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Zeljko_Petrovic, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Cup, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/MISC
# Subject: http://example.org/CZECH, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/MISC
# Subject: http://example.org/31%2C000_1%2C914%2C000, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Jonathan_Wright, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Nazi, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/MISC
# Subject: http://example.org/FIFA, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Ulker_Spor, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Budapest, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/Andreas_Thom, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Munich, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/B._Nielsen, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/da_Silva, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Klaus, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Carcass_Basis, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Genoa, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Luis_Milla, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Italy_1996-12-06, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/Ray_Buchanan, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Steven_Waltman, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/12/15/2013_1%2C135M_5.30_5.35, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/which, Predicate: http://example.org/sign, Object: http://example.org/government
# Subject: http://example.org/Moin_Khan, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/New_Zealand, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/Chelsea, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Andy_Capicik, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/BEIJING_1996-12-06, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/Beirut, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/Ljubljana, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/DUBLIN_1996-12-07, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/Jim_Moran, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Eric_Cleymans, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/One, Predicate: http://example.org/close, Object: http://example.org/authorities
# Subject: http://example.org/Euro, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/MISC
# Subject: http://example.org/Ajax, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Juan_Roque, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Haitham_Haddadin, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/GLASGOW_1996-12-07, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/Svetlana_Jhurova, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/27._Sybille, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Y-GREEN_BAY, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Democrats, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/MISC
# Subject: http://example.org/Oleg_Shatskiku, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Artur_Lekbello, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/National_Weather_Service, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/K._Benjamin, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Oct_97_68.00_68.05_63.98_65.43-70.16, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/PARIS_1996-12-06, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/SAN_JOSE, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/John_Paul, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Gilbert_Le_Gras, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Hull, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/MOSCOW_1996-12-06, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/Hibernian, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Flax_165.2_181.9_14.9_231.4_332.9, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Ian_Wright, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Michael_Frederick, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Sali_Berisha, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/International_Bonds, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Standings_of_National, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/12/15/2000_1%2C250M_6.25_4.10, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Sep_97_69.18_69.24_65.17_66.61-71.34, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/SINGAPORE_1996-12-06, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/Blackburn, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Sergio_Conceicao, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Central_Africa, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/Nicholas_Burns, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Mar_97_76.37_76.12_72.02_73.47-78.24, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Estudiantes_Madrid, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/JCPenney_Classic, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/MISC
# Subject: http://example.org/Zywiec, Predicate: http://example.org/boost, Object: http://example.org/shedding
# Subject: http://example.org/Piacenza, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Paul_Keating, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Gerard_Van_Velde, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Guy_Whittingham, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Chilean, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/MISC
# Subject: http://example.org/12/15/2011_1%2C240M_5.25_5.25, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Alexander_Bavykin, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Bayern_Munich, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Grain_Commission, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/ATLANTIC_DIVISION, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/MISC
# Subject: http://example.org/Slovenia_432, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/Olympic, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/MISC
# Subject: http://example.org/DALLAS, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/Kuwait, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/RTRS, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Liviu_Ciobotariu_of_National_Bucharest, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/EASTERN_DIVISION, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/MISC
# Subject: http://example.org/Bure, Predicate: http://example.org/suspend, Object: http://example.org/League
# Subject: http://example.org/TORONTO, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/East_Stirling, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Olympiakos, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Scottish, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/MISC
# Subject: http://example.org/UEFA, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Mediterranean, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/MISC
# Subject: http://example.org/conditions, Predicate: http://example.org/meet, Object: http://example.org/airlines
# Subject: http://example.org/Estonia, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/centre-left_Social_Democrats, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Joao_Manuel_Pinto, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Oats_40.0_561.0_391.9_4.8_149.6_115.0, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Lee_Young, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Martin_Londgaard_Hansen, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Low_sulphur, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Kyi, Predicate: http://example.org/restrict, Object: http://example.org/government
# Subject: http://example.org/Twente_Enschede, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Dunfermline, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/BARCELONA, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Peterborough, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Manchester_City, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Irish, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/MISC
# Subject: http://example.org/Southend, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/ETA, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Nobel_Peace_Prize, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/MISC
# Subject: http://example.org/Waqar_Younis, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Finland_1996-12-07, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/S._Law, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/19%3D_Kate, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/15%2C232, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/WORLD_CUP_SUPER, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/MISC
# Subject: http://example.org/Jason_Gillespie, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Bradford, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Chris_Witty, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Robert_Mugabe, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Australia_1996-12-07, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/Indian, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/MISC
# Subject: http://example.org/GUNMEN_WOUND, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Mesipia_77.5, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/S%26P, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Rapid_Vienna, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/West_Coast_Vessel_Loadings, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/24._Megan, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Parma, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/VfL_Bochum, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/WELLINGTON_1996-12-06, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/Robert, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Jorge_Cadete, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/EU, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Bristol_Rovers, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Reuters, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Matthew_Burke, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Anke_Baler, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/246_334, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/League_title-holders_Steaua_Bucharest, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/SAN_ANTONIO, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/FC_Hansa_Rostock, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Roman_Catholic, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/MISC
# Subject: http://example.org/Corn_4.4_15.1_87.0_0.6_22.1_11.1, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/ALPINE_SKIING-GLADISHIVA, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/SAN, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/Norway, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/Jose_Amavisca, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Moslem, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/MISC
# Subject: http://example.org/SAN_ANTONIO_89, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Sweden_673, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/C%24, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/MISC
# Subject: http://example.org/United_Arab_Emirates_1996-12-06, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/Shaun_Young, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Blanc_collected, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Volendam, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Jun_97_77.53_77.24_73.17_74.62-79.35, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Pernilla_Wiberg, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Torquay, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Ivan_de, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Viktor_Paco, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Bob_Woolmer, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Rubin, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/BRATISLAVA_1996-12-06, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/English, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/MISC
# Subject: http://example.org/221_368, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/HOUSTON, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/Zahoor_Elahi, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/laPena, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Jeon_Woon, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/African_National_Congress, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Deligst_20/11/96, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Auxerre, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Yeltsin, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Play_restarted, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Pro-European_Conservative, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/South_America, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/PLO, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/which, Predicate: http://example.org/patrol, Object: http://example.org/troops
# Subject: http://example.org/Neil_Back, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Crude_petroleum_2%2C557_2%2C832_15%2C838_17%2C648, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/London_Stock_Exchange, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Jack_Charlton, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Marcus_Gayle, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/MIAMI, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/U.S.-based_MCI_Communications_Corporation, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/St_Mirren, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Nairobi, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/Scott_McCarron, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Australian, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/MISC
# Subject: http://example.org/Electronic_Data, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Ricky_Ponting, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/World, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/MISC
# Subject: http://example.org/NEW_ORLEANS, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/Arminia_Bielefeld, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Laurent_Kabila, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/San, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/10%3D_Megan, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Hearts, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Stefanel_Milan, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/West_Coast, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Palestine_Liberation_Organisation, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Falkirk, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Jiri_Dzmura, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Veronica_Brenner, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/PITTSBURGH, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Manchester_United, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Doncaster, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/OAKLAND, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Saint_Nicholas, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/which, Predicate: http://example.org/guard, Object: http://example.org/soldiers
# Subject: http://example.org/National_League_for_Democracy, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Carlos_Ponce, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Florida_Supreme_Court, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Bnei_Yehuda, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Cape_Town, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/Royal_Clipper, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Hapoel_Taibe, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Allan_Budi, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Egyptian, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/MISC
# Subject: http://example.org/28%2C418, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/GRAND_SLAM_CUP, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/MISC
# Subject: http://example.org/SOFIA_1996-12-06, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/1-11_2-38_3-64_4-73_5-81_6-120_7-135_8-150, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/DAX, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/MISC
# Subject: http://example.org/United_Arab_Emirates, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/PaineWebber_Incorporated, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/C._Harris, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Chile, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/Clinton_Whitelaw, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Andrei_Ivanov, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Mohammed_Rashid, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Andrew, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/ceremony, Predicate: http://example.org/attend, Object: http://example.org/Constantinescu
# Subject: http://example.org/Notts_County, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/responses, Predicate: http://example.org/make, Object: http://example.org/Jan.
# Subject: http://example.org/Finland, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/Republic_of_Ireland, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/Coventry, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Elif_Kaban, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Internet, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/MISC
# Subject: http://example.org/Elgin_City, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/WORLD_CUP, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/MISC
# Subject: http://example.org/Stirling, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Oats, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/James_Love, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/WASHINGTON, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/Polish, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/MISC
# Subject: http://example.org/Czech_Republic, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/World_Trade_Organisation, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Evelyn_Leopold, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Mark_Murless, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Kenneth_Clarke, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Balkan, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/Canadian, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/MISC
# Subject: http://example.org/Saitoh_121, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/India_1996-12-06, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/Dejan_Savicevic, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Inter, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Saudi_Arabia, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/Indian_Ocean, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/Welsh, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/MISC
# Subject: http://example.org/OMAHA_1996-12-06, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/ST._LOUIS_1996-12-06, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Daniel_Bravo, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Abidjan, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/HOUSTON, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/13050.2_11979.6, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Greg_Blewett, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/CINCINNATI, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Carl_Hooper, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/33-1_Fernando_Sanz_25-1, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/FBI, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Hereford, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Christophe_Grelombe, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Czech, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/MISC
# ...
# Subject: http://example.org/World_Cup, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/MISC
# Subject: http://example.org/State_Street_Bank_and_Trust_Company, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Asian, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/MISC
# Subject: http://example.org/George_Weah, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Kim_Pan, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Hansa_Rostock, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Milan_Rapajic, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Foreign_Affairs_Department, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Tranmere, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Cardiff, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/SEATTLE, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Jim_Courier, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/White_House, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/Hwang_Sun_Hong, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/it, Predicate: http://example.org/take, Object: http://example.org/others
# Subject: http://example.org/Ye_Zhaoying, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/CIS, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/RADIO_ROMANIA, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Daniel_Manu, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Real_Madrid_Real_Madrid, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/2-225_3-240_4-247_5-252_6-260_7-261_8-269_9-276, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Mario_Stanic, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Fung_Permadi, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Bellerive_Oval, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/3-3_50-1, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Mark_Cairns, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/UK, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/Soviet, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/MISC
# Subject: http://example.org/Antonio_Folha, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/CSKA_Moscow, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/JERUSALEM_1996-12-06, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/Nigel_Walker, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Craig_Quinnell, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Cibona_Zagreb, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/David_Giffin, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Hapoel_Haifa, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/North_America, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/Riga_Newsroom, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Asian_Games, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/MISC
# Subject: http://example.org/J._Vaughan, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/AZ_Alkmaar, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/California, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/Hosni_Mubarak, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Athletic_Bilbao, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/HARARE_1996-12-07, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/Santiago_Bernabeu, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/LOMBARDI_AWARD, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Sheffield, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Kohl, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Swiss, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/MISC
# Subject: http://example.org/BUCHAREST_1996-12-06, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/28._Alexandra, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Bayer_Leverkusen, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Palestinian_Authority, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/POLAND, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/PT, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/LOS_ANGELES, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Jose_Taira, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Edna_Fernandes, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Porto_central, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Mark_Cayeux, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Vitesse_Arnhem, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Peres, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Hungary, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/Credit_Suisse, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/N.J._1996-12-06, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/Bastia, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Andrea_Sgorlon, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Japanese, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/MISC
# Subject: http://example.org/LONDON_1996-12-06, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/CAIRO_1996-12-06, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/Popescu, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Shimizu_Hiroyasu, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Jimmy_Adams, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Montana, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/ALPINE_SKIING-WOMEN_%27S_DOWNHILL_WINNER_PROFILE, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Atlanta, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/18%3D_Marianne, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Germany, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/SAN_FRANCISCO, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/12/15/2009_1%2C240M_5.05_5.05, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Richard_Eglin, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Venezuela, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/Slovenia, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/BEIRUT_1996-12-06, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/Sean_Olsson, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Tirana, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/Phoenix_101_SACRAMENTO_95, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/MISC
# Subject: http://example.org/Carlo_Checchinato, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/19%2C675, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Myos_Yang, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/David_Dofara, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Zaire, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/Allan_Bateman, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/DENVER, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Shahid_Afridi, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Benjamin_9.4-0-43-1, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/2016_5.35, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/10%3D_Stefanie, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Monaco, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Sebastien_Foucras, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/ST_LOUIS, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Everton, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Mohamed_Benchaou, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Real_Madrid_Barcelona, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Peter_van, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/BANGUI_1996-12-06, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/12/15/2014_850M_5.30_5.35, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Ryan_Johnson, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Dan_Cuo, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/L._Germon, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/United_City_Bank, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Alena_Koroleva, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Republic, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/LOC
# Subject: http://example.org/Indra_Wijaya, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/Tutsi, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/MISC
# Subject: http://example.org/Swansea, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/ORG
# Subject: http://example.org/Roberto_Mancini, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER
# Subject: http://example.org/C._Cairns, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://example.org/PER

# %% [markdown]
# We decided to serialize the graph to a .ttl file

# %%
g.serialize("knowledge_graph.ttl", format="turtle")
num_triples = len(g)
print(f"The graph contains {num_triples} triples.")
# Out:
# The graph contains 1912 triples.

# %% [markdown]
# Now we want to run the programm on the following text : Star Wars IV is a Movie where there are different kinds of creatures, like humans and wookies. Some creatures are Jedis; for instance, the human Luke is a Jedi, and Master Yoda – for whom the species is not known – is also a Jedi. The wookie named Chewbacca is Han’s co-pilot on the Millennium Falcon starship. The speed of Millennium Falcon is 1.5 (above the speed of light!)

# %%
# Define a namespace
EX = Namespace("http://sw.org/")

# Create an RDF graph
g = Graph()

# Add entities and their types
g.add((URIRef(EX["Star_Wars_IV"]), RDF.type, URIRef(EX["Movie"])))
g.add((URIRef(EX["humans"]), RDF.type, URIRef(EX["Species"])))
g.add((URIRef(EX["wookies"]), RDF.type, URIRef(EX["Species"])))
g.add((URIRef(EX["Luke"]), RDF.type, URIRef(EX["Human"])))
g.add((URIRef(EX["Luke"]), RDF.type, URIRef(EX["Jedi"])))
g.add((URIRef(EX["Master_Yoda"]), RDF.type, URIRef(EX["Jedi"])))
g.add((URIRef(EX["Master_Yoda"]), RDF.type, URIRef(EX["Unknown_Species"])))
g.add((URIRef(EX["Chewbacca"]), RDF.type, URIRef(EX["Wookie"])))
g.add((URIRef(EX["Millennium_Falcon"]), RDF.type, URIRef(EX["Starship"])))

# Add relations
g.add((URIRef(EX["Chewbacca"]), URIRef(EX["is_co_pilot_of"]), URIRef(EX["Millennium_Falcon"])))
g.add((URIRef(EX["Millennium_Falcon"]), URIRef(EX["has_speed"]), Literal(1.5)))
g.add((URIRef(EX["Millennium_Falcon"]), URIRef(EX["speed_unit"]), Literal("above the speed of light")))

# Serialize the graph to a file (optional)
g.serialize("star_wars_knowledge_graph.ttl", format="turtle")

# SPARQL query to verify the graph
query = """
SELECT ?subject ?predicate ?object
WHERE {
    # ?subject ?predicate ?object .
}
"""

# Execute the query
results = g.query(query)

# Print the results
for row in results:
    print(f"Subject: {row.subject}, Predicate: {row.predicate}, Object: {row.object}")
# Out:
# Subject: http://sw.org/Luke, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://sw.org/Human
# Subject: http://sw.org/Master_Yoda, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://sw.org/Unknown_Species
# Subject: http://sw.org/Star_Wars_IV, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://sw.org/Movie
# Subject: http://sw.org/wookies, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://sw.org/Species
# Subject: http://sw.org/Master_Yoda, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://sw.org/Jedi
# Subject: http://sw.org/Millennium_Falcon, Predicate: http://sw.org/has_speed, Object: 1.5
# Subject: http://sw.org/Millennium_Falcon, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://sw.org/Starship
# Subject: http://sw.org/humans, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://sw.org/Species
# Subject: http://sw.org/Luke, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://sw.org/Jedi
# Subject: http://sw.org/Chewbacca, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://sw.org/Wookie
# Subject: http://sw.org/Millennium_Falcon, Predicate: http://sw.org/speed_unit, Object: above the speed of light
# Subject: http://sw.org/Chewbacca, Predicate: http://sw.org/is_co_pilot_of, Object: http://sw.org/Millennium_Falcon

# %% [markdown]
# ## TASK 2: PIPELINE FOR KNOWLEDGE GRAPH CONSTRUCTION

# %% [markdown]
# ### 1. FETCH NEWS ARTICLE

# %% [markdown]
# ### 2. USE METHODS FORM TASK 1

# %% [markdown]
# # PART 2
